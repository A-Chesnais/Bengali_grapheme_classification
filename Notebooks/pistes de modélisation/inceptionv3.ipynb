# %%
import gc
import time
from tqdm import tqdm
import cv2
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score

from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input, AveragePooling2D
from keras.applications import inception_v3
from keras.optimizers import Adam
from keras.callbacks import Callback

from keras.utils import plot_model
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# /kaggle/input/bengali-graphemes-croppedresized-100x100-train/train_data_1.feather
# /kaggle/input/bengali-graphemes-croppedresized-100x100-train/train_data_3.feather
# /kaggle/input/bengali-graphemes-croppedresized-100x100-train/train_data_0.feather
# /kaggle/input/bengali-graphemes-croppedresized-100x100-train/train_data_2.feather
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet

# %%
train_target = pd.read_csv('/kaggle/input/bengaliai-cv19/train.csv', index_col='image_id')

# %%
rootLB = LabelBinarizer()
vowelLB = LabelBinarizer()
consonantLB = LabelBinarizer()
rootLB.fit(train_target['grapheme_root'])
vowelLB.fit(train_target['vowel_diacritic'])
consonantLB.fit(train_target['consonant_diacritic'])
# Out:
# LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)

# %% [markdown]
# # Custom modules

# %% [markdown]
# ## Custom metric callback

# %%
class validation_recall(keras.callbacks.Callback):
    
    def __init__(self, validation_data=()):
        super(keras.callbacks.Callback, self).__init__()
        self.X_val, self.y_val = validation_data
    
    def on_epoch_end(self, epoch, logs={}):

        root_val = self.y_val[0]
        vowel_val = self.y_val[1]
        consonant_val = self.y_val[2]
        
        # Predictions on validation set for the 3 targets 
        #(+ one hot encoding)
        preds = self.model.predict(inception_v3.preprocess_input(self.X_val))
        
        root_preds = np.zeros_like(preds[0])
        root_preds[np.arange(len(preds[0])), 
                   preds[0].argmax(axis=1)] = 1
        
        vowel_preds = np.zeros_like(preds[1])
        vowel_preds[np.arange(len(preds[1])), 
                    preds[1].argmax(axis=1)] = 1
        
        consonant_preds = np.zeros_like(preds[2])
        consonant_preds[np.arange(len(preds[2])), 
                        preds[2].argmax(axis=1)] = 1
        
        # Recall calculation for the 3 targets
        root_recall = recall_score(root_val, root_preds, 
                                   average='macro')
        vowel_recall = recall_score(vowel_val, vowel_preds, 
                                    average='macro')
        consonant_recall = recall_score(consonant_val, consonant_preds, 
                                        average='macro')
        final_score = np.average([root_recall, vowel_recall, 
                                  consonant_recall], weights=[2,1,1])
        
        # Displaying scores at the end of each epoch
        print(' - root_recall: {0:.4f}'.format(root_recall)+\
              ' - vowel_recall: {0:.4f}'.format(vowel_recall)+\
              ' - consonant_recall: {0:.4f}'.format(consonant_recall)+\
              ' - final_score: {0:.4f}'.format(final_score))

        # Saving scores in logs history
        logs['root_recall'] = root_recall
        logs['vowel_recall'] = vowel_recall
        logs['consonant_recall'] = consonant_recall
        logs['final_score'] = final_score
        
        del root_val
        del vowel_val
        del consonant_val
        del preds 
        del root_preds 
        del vowel_preds
        del consonant_preds
        gc.collect()

# %% [markdown]
# ## Custom data loader

# %% [markdown]
# Keras DataGenerator modified for multi-outputs model taken from [this very interesting notebook](https://www.kaggle.com/kaushal2896/bengali-graphemes-starter-eda-multi-output-cnn#Basic-Model) from Kaushal Shah. It will allow to generate a batch of data to feed the model while training to avoid memory shortage.

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, 
                                         batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %% [markdown]
# ## Resizing function

# %%
HEIGHT = 137
WIDTH = 236
CROP_SIZE = 80

# %%
def crop_and_resize_images(df, resized_df, resize_size = CROP_SIZE):
    cropped_imgs = {}
    for img_id in tqdm(range(df.shape[0])):
        img = resized_df[img_id]
        _, thresh = cv2.threshold(img, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]
        
        idx = 0 
        ls_xmin = []
        ls_ymin = []
        ls_xmax = []
        ls_ymax = []
        for cnt in contours:
            idx += 1
            x,y,w,h = cv2.boundingRect(cnt)
            ls_xmin.append(x)
            ls_ymin.append(y)
            ls_xmax.append(x + w)
            ls_ymax.append(y + h)
        xmin = min(ls_xmin)
        ymin = min(ls_ymin)
        xmax = max(ls_xmax)
        ymax = max(ls_ymax)

        roi = img[ymin:ymax,xmin:xmax]
        resized_roi = cv2.resize(roi, (resize_size, resize_size))
        cropped_imgs[df.image_id[img_id]] = resized_roi.reshape(-1)
        
    resized = pd.DataFrame(cropped_imgs).T.reset_index()
    resized.columns = resized.columns.astype(str)
    resized.rename(columns={'index':'image_id'},inplace=True)
    return resized #out_df

# %% [markdown]
# # Model definition

# %%
def create_inception_model():
   
    inputs = Input(shape=(80,80,1))
    base_model = inception_v3.InceptionV3(include_top=False, weights=None, input_tensor=inputs, pooling='avg')
    x = base_model.output
    
    x = Dense(1024, activation = "relu")(x)
    x = Dropout(rate=0.3)(x)
    x = Dense(512, activation = "relu")(x)
    x = Dropout(rate=0.3)(x)
    
    root_out = Dense(168, activation='softmax', name='root_output')(x)
    vowel_out = Dense(11, activation='softmax', name='vowel_output')(x)
    consonant_out = Dense(7, activation='softmax', name='consonant_output')(x)

    model = Model(inputs=inputs, outputs=[root_out, vowel_out, consonant_out])
    
    return model

# %% [markdown]
# # Training function :

# %% [markdown]
# This training function is using the following process :
# * Loading a set of images and targets data (from one of the four images files)
# * Reshape images data to numpy array with correct dimensions (100 x 100)
# * One hot encoding of the 3 targets
# * Separate all sets in two : training set and validation set
# * Creating Keras data generators to load data batch by batch in the model
# * Train the model

# %%
def train_model(model, epochs, batch_size):
    complete_history = []
    for j in range(epochs):
        print('current epoch : ' + str(j+1) + ' / ' + str(epochs))
        for i in range(4):

            # Images + targets loading and merging
            train_data = pd.read_feather('/kaggle/input/bengali-graphemes-'
                                         'croppedresized-100x100-train/'
                                         f'train_data_{i}.feather')
            train_data.set_index(keys=['image_id'], drop=True, inplace=True)
            train_df = pd.merge(train_data, train_target, 
                                on='image_id').drop(['grapheme'], axis=1)

            # Deleting previous variables to free up memory
            del train_data
            gc.collect()

            # One hot encoding the 3 targets with sklearn LabelBinarizer
            #rootLB = LabelBinarizer()
            #vowelLB = LabelBinarizer()
            #consonantLB = LabelBinarizer()
            rootLabels = rootLB.transform(train_df['grapheme_root'])
            vowelLabels = vowelLB.transform(train_df['vowel_diacritic'])
            consonantLabels = consonantLB.transform(
                              train_df['consonant_diacritic'])

            # Reshape images data to numpy array with same dimensions 
            # as images (80 x 80)
            train_df.drop(['grapheme_root', 'vowel_diacritic', 
                           'consonant_diacritic'], axis=1, inplace=True)
            #train_df = train_df / 255
            train_images = train_df.values.reshape(-1, 80, 80, 1)

            # Deleting previous variables to free up memory
            del train_df
            gc.collect()

            # Creating Train / validation set for images and 3 targets
            X_train, X_val, y_train_root, y_val_root, y_train_vowel, \
            y_val_vowel, y_train_consonant, y_val_consonant \
            = train_test_split(train_images, rootLabels, vowelLabels, 
                               consonantLabels, test_size=0.2, 
                               random_state=42)

            # Deleting previous variables to free up memory
            del train_images
            del rootLabels, vowelLabels, consonantLabels
            gc.collect()

            # Creation of Keras Datagenerator configuration 
            # without data augmentation
            datagen = MultiOutputDataGenerator(
            featurewise_center=False,  
            samplewise_center=False,
            featurewise_std_normalization=False,
            samplewise_std_normalization=False,
            zca_whitening=False,
            rotation_range=0,
            zoom_range=0,
            width_shift_range=0,
            height_shift_range=0,
            horizontal_flip=False,
            vertical_flip=False,
            preprocessing_function=inception_v3.preprocess_input)

            ''' You can use this piece of code to have insight of how the 
                datagen works and how batch are structured

            i = 0
            for batch in datagen.flow(X_train, 
                                     {'root': y_train_root, 
                                     'vowel': y_train_vowel, 
                                     'consonant': y_train_consonant},
                                      batch_size=1, save_to_dir=None):
                print(i)
                print('batch infos :')
                print(f'type : {type(batch)}')
                print(f'length type : {len(batch)}')
                print('features infos :')
                print(f'type : {type(batch[0])}')
                print(f'shape : {batch[0].shape}')
                print('Target infos :')
                print(f' global type : {type(batch[1])}')
                print(f'global shape : {len(batch[1])}')
                print(f'first target shape : {batch[1]["root"].shape}')
                print(f'second target shape : {batch[1]["vowel"].shape}')
                print(f'third target shape : {batch[1]["consonant"].shape}')

                i += 1
                if i > 5:
                    break  # otherwise the generator would loop indefinitely

            '''
            # creation of data generator for training set
            train_generator = datagen.flow(X_train,
                                           {'root_output': y_train_root, 
                                            'vowel_output': y_train_vowel, 
                                            'consonant_output': y_train_consonant},
                                           batch_size=batch_size)

            # creation of data generator for validation set
            val_generator = datagen.flow(X_val,
                                         {'root_output': y_val_root, 
                                          'vowel_output': y_val_vowel, 
                                          'consonant_output': y_val_consonant},
                                         batch_size=batch_size)

            # Creation of callback for metric calculation
            # after each epoch
            my_call = validation_recall(validation_data=(X_val,
                                                         [y_val_root,
                                                          y_val_vowel, 
                                                          y_val_consonant]))

            # Model training
            history = model.fit_generator(
                    train_generator,
                    steps_per_epoch=X_train.shape[0] // batch_size,
                    epochs=1,
                    validation_data=val_generator,
                    validation_steps=X_val.shape[0] // batch_size,
                    callbacks=[my_call])

            # Appending training history to the one of previous
            complete_history.append(history.history)

            del train_generator
            del val_generator
            del my_call
            del X_train
            del X_val
            del y_train_root
            del y_val_root
            del y_train_vowel
            del y_val_vowel
            del y_train_consonant
            del y_val_consonant
            gc.collect()

    return model, complete_history

# %% [markdown]
# # Model training

# %%
model = create_inception_model()

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 80, 80, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 39, 39, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 39, 39, 32)   96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 39, 39, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 37, 37, 32)   9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 37, 37, 32)   96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 37, 37, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 37, 37, 64)   18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 37, 37, 64)   192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 37, 37, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 18, 18, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 18, 18, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 18, 18, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 18, 18, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 192)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 64)     12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, 7, 64)     192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 64)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 48)     9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 96)     55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 7, 7, 48)     144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 7, 7, 96)     288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 48)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 96)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 7, 7, 192)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 64)     12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 64)     76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 96)     82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 32)     6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 7, 64)     192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 7, 7, 64)     192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 96)     288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 32)     96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 64)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 64)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 96)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 32)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 7, 7, 256)    0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 7, 7, 64)     16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 64)     192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, 7, 64)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 7, 7, 48)     12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 7, 7, 96)     55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 48)     144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 96)     288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 48)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 7, 7, 96)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 7, 7, 256)    0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 7, 7, 64)     16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 7, 7, 64)     76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 7, 7, 96)     82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 7, 7, 64)     16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 7, 7, 64)     192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 64)     192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 96)     288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 7, 7, 64)     192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 64)     0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 64)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 7, 7, 96)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 7, 7, 64)     0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 7, 7, 288)    0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 7, 7, 64)     18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, 7, 64)     192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 7, 7, 64)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 7, 7, 48)     13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 7, 7, 96)     55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 7, 7, 48)     144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 7, 7, 96)     288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 7, 7, 48)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 7, 7, 96)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 7, 7, 288)    0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 7, 7, 64)     18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 7, 7, 64)     76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 7, 7, 96)     82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 7, 7, 64)     18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 7, 7, 64)     192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, 7, 64)     192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 7, 7, 96)     288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 7, 7, 64)     192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 7, 7, 64)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 7, 7, 64)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 7, 7, 96)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 7, 7, 64)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 7, 7, 288)    0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 7, 7, 64)     18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 7, 7, 64)     192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 7, 7, 64)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 7, 7, 96)     55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 7, 7, 96)     288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 7, 7, 96)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 3, 3, 384)    995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 3, 3, 96)     82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 3, 3, 384)    1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 3, 3, 96)     288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 3, 3, 384)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 3, 3, 96)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 3, 3, 288)    0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 3, 3, 768)    0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 3, 3, 128)    98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 3, 3, 128)    384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 3, 3, 128)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 3, 3, 128)    114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 3, 3, 128)    384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 3, 3, 128)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 3, 3, 128)    98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 3, 3, 128)    114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 3, 3, 128)    384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 3, 3, 128)    384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 3, 3, 128)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 3, 3, 128)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 3, 3, 128)    114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 3, 3, 128)    114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 3, 3, 128)    384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 3, 3, 128)    384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 3, 3, 128)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 3, 3, 128)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 3, 3, 768)    0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 3, 3, 192)    147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 3, 3, 192)    172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 3, 3, 192)    172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 3, 3, 192)    147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 3, 3, 192)    576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 3, 3, 192)    576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 3, 3, 192)    576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 3, 3, 192)    576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 3, 3, 192)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 3, 3, 192)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 3, 3, 192)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 3, 3, 192)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 3, 3, 768)    0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 3, 3, 160)    122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 3, 3, 160)    480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 3, 3, 160)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 3, 3, 160)    179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 3, 3, 160)    480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 3, 3, 160)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 3, 3, 160)    122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 3, 3, 160)    179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 3, 3, 160)    480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 3, 3, 160)    480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 3, 3, 160)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 3, 3, 160)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 3, 3, 160)    179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 3, 3, 160)    179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 3, 3, 160)    480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 3, 3, 160)    480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 3, 3, 160)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 3, 3, 160)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 3, 3, 768)    0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 3, 3, 192)    147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 3, 3, 192)    215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 3, 3, 192)    215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 3, 3, 192)    147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 3, 3, 192)    576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 3, 3, 192)    576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 3, 3, 192)    576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 3, 3, 192)    576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 3, 3, 192)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 3, 3, 192)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 3, 3, 192)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 3, 3, 192)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 3, 3, 768)    0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 3, 3, 160)    122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 3, 3, 160)    480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 3, 3, 160)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 3, 3, 160)    179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 3, 3, 160)    480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 3, 3, 160)    0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 3, 3, 160)    122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 3, 3, 160)    179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 3, 3, 160)    480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 3, 3, 160)    480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 3, 3, 160)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 3, 3, 160)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 3, 3, 160)    179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 3, 3, 160)    179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 3, 3, 160)    480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 3, 3, 160)    480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 3, 3, 160)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 3, 3, 160)    0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 3, 3, 768)    0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 3, 3, 192)    147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 3, 3, 192)    215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 3, 3, 192)    215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 3, 3, 192)    147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 3, 3, 192)    576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 3, 3, 192)    576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 3, 3, 192)    576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 3, 3, 192)    576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 3, 3, 192)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 3, 3, 192)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 3, 3, 192)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 3, 3, 192)    0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 3, 3, 768)    0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 3, 3, 192)    147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 3, 3, 192)    576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 3, 3, 192)    0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 3, 3, 192)    258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 3, 3, 192)    576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 3, 3, 192)    0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 3, 3, 192)    147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 3, 3, 192)    258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 3, 3, 192)    576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 3, 3, 192)    576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 3, 3, 192)    0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 3, 3, 192)    0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 3, 3, 192)    258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 3, 3, 192)    258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 3, 3, 192)    576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 3, 3, 192)    576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 3, 3, 192)    0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 3, 3, 192)    0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 3, 3, 768)    0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 3, 3, 192)    147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 3, 3, 192)    258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 3, 3, 192)    258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 3, 3, 192)    147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 3, 3, 192)    576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 3, 3, 192)    576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 3, 3, 192)    576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 3, 3, 192)    576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 3, 3, 192)    0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 3, 3, 192)    0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 3, 3, 192)    0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 3, 3, 192)    0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 3, 3, 768)    0           activation_61[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 1, 1, 192)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 1, 1, 1280)   0           activation_72[0][0]
#                                                                  activation_76[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 1, 1, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 1, 1, 448)    1344        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 1, 1, 448)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 1, 1, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 1, 1, 384)    1548288     activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 1, 1, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 1, 1, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 1, 1, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 1, 1, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 1, 1, 384)    442368      activation_78[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 1, 1, 384)    442368      activation_78[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 1, 1, 384)    442368      activation_82[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 1, 1, 384)    442368      activation_82[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 1, 1, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 1, 1, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 1, 1, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 1, 1, 384)    1152        conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 1, 1, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 1, 1, 384)    1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 1, 1, 192)    245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 1, 1, 320)    960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 1, 1, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 1, 1, 384)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 1, 1, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 1, 1, 384)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 1, 1, 192)    576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 1, 1, 320)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 1, 1, 768)    0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1, 1, 768)    0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 1, 1, 192)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 1, 1, 2048)   0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 1, 1, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 1, 1, 448)    1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 1, 1, 448)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 1, 1, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 1, 1, 384)    1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 1, 1, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 1, 1, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 1, 1, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 1, 1, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 1, 1, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 1, 1, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 1, 1, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 1, 1, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 1, 1, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 1, 1, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 1, 1, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 1, 1, 384)    1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 1, 1, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 1, 1, 384)    1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 1, 1, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 1, 1, 320)    960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 1, 1, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 1, 1, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 1, 1, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 1, 1, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 1, 1, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 1, 1, 320)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 1, 1, 768)    0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 1, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 1, 1, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 1, 1, 2048)   0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# root_output (Dense)             (None, 168)          86184       dropout_2[0][0]
# __________________________________________________________________________________________________
# vowel_output (Dense)            (None, 11)           5643        dropout_2[0][0]
# __________________________________________________________________________________________________
# consonant_output (Dense)        (None, 7)            3591        dropout_2[0][0]
# ==================================================================================================
# Total params: 24,520,602
# Trainable params: 24,486,170
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', 
              metrics=None)

# %%
trained_model, history = train_model(model=model, epochs=30, 
                                     batch_size=256)
# Out:
# current epoch : 1 / 30
# Epoch 1/1
# 156/156 [==============================] - 87s 557ms/step - loss: 7.4333 - root_output_loss: 4.7070 - vowel_output_loss: 1.6351 - consonant_output_loss: 1.0912 - val_loss: 8.4549 - val_root_output_loss: 4.7732 - val_vowel_output_loss: 2.4868 - val_consonant_output_loss: 1.2408
#  - root_recall: 0.0060 - vowel_recall: 0.0916 - consonant_recall: 0.1429 - final_score: 0.0616
# Epoch 1/1
# 156/156 [==============================] - 44s 283ms/step - loss: 6.2022 - root_output_loss: 4.3294 - vowel_output_loss: 0.9642 - consonant_output_loss: 0.9085 - val_loss: 11.6824 - val_root_output_loss: 6.7371 - val_vowel_output_loss: 2.9381 - val_consonant_output_loss: 2.0249
#  - root_recall: 0.0079 - vowel_recall: 0.2033 - consonant_recall: 0.2385 - final_score: 0.1144
# Epoch 1/1
# 156/156 [==============================] - 44s 282ms/step - loss: 5.4330 - root_output_loss: 3.9677 - vowel_output_loss: 0.7320 - consonant_output_loss: 0.7332 - val_loss: 7.7675 - val_root_output_loss: 5.1583 - val_vowel_output_loss: 1.2215 - val_consonant_output_loss: 1.1179
#  - root_recall: 0.0164 - vowel_recall: 0.5153 - consonant_recall: 0.3618 - final_score: 0.2274
# Epoch 1/1
# 156/156 [==============================] - 44s 280ms/step - loss: 4.7264 - root_output_loss: 3.5713 - vowel_output_loss: 0.5800 - consonant_output_loss: 0.5752 - val_loss: 5.8153 - val_root_output_loss: 4.1670 - val_vowel_output_loss: 0.7812 - val_consonant_output_loss: 0.7159
#  - root_recall: 0.0621 - vowel_recall: 0.6566 - consonant_recall: 0.5295 - final_score: 0.3276
# current epoch : 2 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 283ms/step - loss: 4.1273 - root_output_loss: 3.1426 - vowel_output_loss: 0.5010 - consonant_output_loss: 0.4836 - val_loss: 4.2013 - val_root_output_loss: 3.3171 - val_vowel_output_loss: 0.5311 - val_consonant_output_loss: 0.4475
#  - root_recall: 0.1366 - vowel_recall: 0.7562 - consonant_recall: 0.6914 - final_score: 0.4302
# Epoch 1/1
# 156/156 [==============================] - 44s 280ms/step - loss: 3.5908 - root_output_loss: 2.7285 - vowel_output_loss: 0.4535 - consonant_output_loss: 0.4088 - val_loss: 3.6589 - val_root_output_loss: 2.8479 - val_vowel_output_loss: 0.3606 - val_consonant_output_loss: 0.3439
#  - root_recall: 0.1845 - vowel_recall: 0.8155 - consonant_recall: 0.7772 - final_score: 0.4904
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 3.1314 - root_output_loss: 2.3517 - vowel_output_loss: 0.4190 - consonant_output_loss: 0.3607 - val_loss: 3.9400 - val_root_output_loss: 2.8025 - val_vowel_output_loss: 0.5021 - val_consonant_output_loss: 0.6112
#  - root_recall: 0.2036 - vowel_recall: 0.8031 - consonant_recall: 0.7330 - final_score: 0.4858
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 2.6270 - root_output_loss: 1.9482 - vowel_output_loss: 0.3675 - consonant_output_loss: 0.3112 - val_loss: 2.2815 - val_root_output_loss: 1.7695 - val_vowel_output_loss: 0.4862 - val_consonant_output_loss: 0.3701
#  - root_recall: 0.4438 - vowel_recall: 0.8185 - consonant_recall: 0.8159 - final_score: 0.6305
# current epoch : 3 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 2.2455 - root_output_loss: 1.6368 - vowel_output_loss: 0.3326 - consonant_output_loss: 0.2761 - val_loss: 2.0779 - val_root_output_loss: 1.4593 - val_vowel_output_loss: 0.3126 - val_consonant_output_loss: 0.2535
#  - root_recall: 0.5117 - vowel_recall: 0.8791 - consonant_recall: 0.8295 - final_score: 0.6830
# Epoch 1/1
# 156/156 [==============================] - 43s 278ms/step - loss: 2.0787 - root_output_loss: 1.4821 - vowel_output_loss: 0.3289 - consonant_output_loss: 0.2678 - val_loss: 8.4404 - val_root_output_loss: 6.0573 - val_vowel_output_loss: 2.6317 - val_consonant_output_loss: 1.5779
#  - root_recall: 0.3746 - vowel_recall: 0.7297 - consonant_recall: 0.7084 - final_score: 0.5468
# Epoch 1/1
# 156/156 [==============================] - 44s 284ms/step - loss: 1.9188 - root_output_loss: 1.3707 - vowel_output_loss: 0.3080 - consonant_output_loss: 0.2402 - val_loss: 2.0554 - val_root_output_loss: 1.3257 - val_vowel_output_loss: 0.2724 - val_consonant_output_loss: 0.2610
#  - root_recall: 0.5517 - vowel_recall: 0.8931 - consonant_recall: 0.8854 - final_score: 0.7205
# Epoch 1/1
# 156/156 [==============================] - 45s 287ms/step - loss: 1.7002 - root_output_loss: 1.1998 - vowel_output_loss: 0.2743 - consonant_output_loss: 0.2261 - val_loss: 1.4621 - val_root_output_loss: 1.0853 - val_vowel_output_loss: 0.2540 - val_consonant_output_loss: 0.2153
#  - root_recall: 0.6453 - vowel_recall: 0.8981 - consonant_recall: 0.8666 - final_score: 0.7639
# current epoch : 4 / 30
# Epoch 1/1
# 156/156 [==============================] - 45s 286ms/step - loss: 2.4570 - root_output_loss: 1.6645 - vowel_output_loss: 0.4599 - consonant_output_loss: 0.3327 - val_loss: 9.1166 - val_root_output_loss: 5.4431 - val_vowel_output_loss: 2.2457 - val_consonant_output_loss: 1.3477
#  - root_recall: 0.0211 - vowel_recall: 0.2884 - consonant_recall: 0.2119 - final_score: 0.1356
# Epoch 1/1
# 156/156 [==============================] - 44s 280ms/step - loss: 2.1331 - root_output_loss: 1.4746 - vowel_output_loss: 0.3644 - consonant_output_loss: 0.2941 - val_loss: 3.0615 - val_root_output_loss: 1.7378 - val_vowel_output_loss: 0.7186 - val_consonant_output_loss: 0.3297
#  - root_recall: 0.4253 - vowel_recall: 0.7204 - consonant_recall: 0.8001 - final_score: 0.5928
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 1.7100 - root_output_loss: 1.1910 - vowel_output_loss: 0.2819 - consonant_output_loss: 0.2371 - val_loss: 12.5380 - val_root_output_loss: 8.2305 - val_vowel_output_loss: 2.7812 - val_consonant_output_loss: 2.4262
#  - root_recall: 0.2854 - vowel_recall: 0.5708 - consonant_recall: 0.5437 - final_score: 0.4213
# Epoch 1/1
# 156/156 [==============================] - 44s 280ms/step - loss: 1.6574 - root_output_loss: 1.1452 - vowel_output_loss: 0.2842 - consonant_output_loss: 0.2280 - val_loss: 1.6811 - val_root_output_loss: 1.0999 - val_vowel_output_loss: 0.2732 - val_consonant_output_loss: 0.2065
#  - root_recall: 0.6547 - vowel_recall: 0.8972 - consonant_recall: 0.8866 - final_score: 0.7733
# current epoch : 5 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 1.6323 - root_output_loss: 1.1256 - vowel_output_loss: 0.2853 - consonant_output_loss: 0.2214 - val_loss: 1.3916 - val_root_output_loss: 1.0404 - val_vowel_output_loss: 0.2278 - val_consonant_output_loss: 0.1774
#  - root_recall: 0.6375 - vowel_recall: 0.9012 - consonant_recall: 0.8831 - final_score: 0.7648
# Epoch 1/1
# 156/156 [==============================] - 44s 283ms/step - loss: 1.5202 - root_output_loss: 1.0352 - vowel_output_loss: 0.2681 - consonant_output_loss: 0.2168 - val_loss: 3.3322 - val_root_output_loss: 2.1239 - val_vowel_output_loss: 0.6259 - val_consonant_output_loss: 0.4702
#  - root_recall: 0.4471 - vowel_recall: 0.7076 - consonant_recall: 0.7393 - final_score: 0.5853
# Epoch 1/1
# 156/156 [==============================] - 44s 280ms/step - loss: 1.3723 - root_output_loss: 0.9396 - vowel_output_loss: 0.2353 - consonant_output_loss: 0.1973 - val_loss: 1.2982 - val_root_output_loss: 0.8806 - val_vowel_output_loss: 0.2481 - val_consonant_output_loss: 0.2027
#  - root_recall: 0.6801 - vowel_recall: 0.8867 - consonant_recall: 0.8736 - final_score: 0.7801
# Epoch 1/1
# 156/156 [==============================] - 44s 283ms/step - loss: 1.1540 - root_output_loss: 0.7840 - vowel_output_loss: 0.1958 - consonant_output_loss: 0.1742 - val_loss: 1.5962 - val_root_output_loss: 0.8072 - val_vowel_output_loss: 0.2012 - val_consonant_output_loss: 0.1923
#  - root_recall: 0.7394 - vowel_recall: 0.9221 - consonant_recall: 0.9111 - final_score: 0.8280
# current epoch : 6 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 1.1196 - root_output_loss: 0.7577 - vowel_output_loss: 0.1934 - consonant_output_loss: 0.1684 - val_loss: 1.2320 - val_root_output_loss: 0.7000 - val_vowel_output_loss: 0.1744 - val_consonant_output_loss: 0.1647
#  - root_recall: 0.7519 - vowel_recall: 0.9353 - consonant_recall: 0.8859 - final_score: 0.8313
# Epoch 1/1
# 156/156 [==============================] - 45s 287ms/step - loss: 1.0789 - root_output_loss: 0.7260 - vowel_output_loss: 0.1940 - consonant_output_loss: 0.1588 - val_loss: 1.0296 - val_root_output_loss: 0.7247 - val_vowel_output_loss: 0.1961 - val_consonant_output_loss: 0.1582
#  - root_recall: 0.7557 - vowel_recall: 0.9303 - consonant_recall: 0.8904 - final_score: 0.8330
# Epoch 1/1
# 156/156 [==============================] - 45s 287ms/step - loss: 0.9986 - root_output_loss: 0.6727 - vowel_output_loss: 0.1757 - consonant_output_loss: 0.1503 - val_loss: 1.4516 - val_root_output_loss: 0.7987 - val_vowel_output_loss: 0.2030 - val_consonant_output_loss: 0.1900
#  - root_recall: 0.7261 - vowel_recall: 0.9164 - consonant_recall: 0.8742 - final_score: 0.8107
# Epoch 1/1
# 156/156 [==============================] - 45s 287ms/step - loss: 0.9145 - root_output_loss: 0.6140 - vowel_output_loss: 0.1593 - consonant_output_loss: 0.1413 - val_loss: 0.7117 - val_root_output_loss: 0.6598 - val_vowel_output_loss: 0.1579 - val_consonant_output_loss: 0.1624
#  - root_recall: 0.7689 - vowel_recall: 0.9408 - consonant_recall: 0.9420 - final_score: 0.8552
# current epoch : 7 / 30
# Epoch 1/1
# 156/156 [==============================] - 45s 286ms/step - loss: 0.9193 - root_output_loss: 0.6095 - vowel_output_loss: 0.1661 - consonant_output_loss: 0.1436 - val_loss: 0.7905 - val_root_output_loss: 0.6182 - val_vowel_output_loss: 0.1522 - val_consonant_output_loss: 0.1394
#  - root_recall: 0.7979 - vowel_recall: 0.9253 - consonant_recall: 0.8968 - final_score: 0.8545
# Epoch 1/1
# 156/156 [==============================] - 44s 284ms/step - loss: 1.0254 - root_output_loss: 0.6814 - vowel_output_loss: 0.1871 - consonant_output_loss: 0.1569 - val_loss: 6.8421 - val_root_output_loss: 3.9699 - val_vowel_output_loss: 1.6985 - val_consonant_output_loss: 0.8889
#  - root_recall: 0.1560 - vowel_recall: 0.3491 - consonant_recall: 0.3654 - final_score: 0.2566
# Epoch 1/1
# 156/156 [==============================] - 44s 284ms/step - loss: 1.0124 - root_output_loss: 0.6787 - vowel_output_loss: 0.1749 - consonant_output_loss: 0.1588 - val_loss: 0.9632 - val_root_output_loss: 0.6985 - val_vowel_output_loss: 0.1801 - val_consonant_output_loss: 0.1437
#  - root_recall: 0.7593 - vowel_recall: 0.9392 - consonant_recall: 0.9122 - final_score: 0.8425
# Epoch 1/1
# 156/156 [==============================] - 44s 282ms/step - loss: 0.9531 - root_output_loss: 0.6245 - vowel_output_loss: 0.1803 - consonant_output_loss: 0.1484 - val_loss: 0.9104 - val_root_output_loss: 0.7501 - val_vowel_output_loss: 0.2074 - val_consonant_output_loss: 0.1965
#  - root_recall: 0.7686 - vowel_recall: 0.9223 - consonant_recall: 0.9119 - final_score: 0.8428
# current epoch : 8 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 284ms/step - loss: 0.8940 - root_output_loss: 0.5884 - vowel_output_loss: 0.1672 - consonant_output_loss: 0.1384 - val_loss: 1.0454 - val_root_output_loss: 0.6853 - val_vowel_output_loss: 0.1746 - val_consonant_output_loss: 0.1575
#  - root_recall: 0.7744 - vowel_recall: 0.9222 - consonant_recall: 0.8901 - final_score: 0.8403
# Epoch 1/1
# 156/156 [==============================] - 44s 282ms/step - loss: 1.2598 - root_output_loss: 0.8328 - vowel_output_loss: 0.2395 - consonant_output_loss: 0.1875 - val_loss: 1.3923 - val_root_output_loss: 0.8651 - val_vowel_output_loss: 0.2161 - val_consonant_output_loss: 0.2145
#  - root_recall: 0.6979 - vowel_recall: 0.9212 - consonant_recall: 0.8677 - final_score: 0.7962
# Epoch 1/1
# 156/156 [==============================] - 44s 283ms/step - loss: 0.9646 - root_output_loss: 0.6391 - vowel_output_loss: 0.1760 - consonant_output_loss: 0.1495 - val_loss: 1.8250 - val_root_output_loss: 1.3915 - val_vowel_output_loss: 0.4206 - val_consonant_output_loss: 0.2590
#  - root_recall: 0.6201 - vowel_recall: 0.8325 - consonant_recall: 0.8183 - final_score: 0.7228
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 0.8795 - root_output_loss: 0.5781 - vowel_output_loss: 0.1635 - consonant_output_loss: 0.1379 - val_loss: 1.1650 - val_root_output_loss: 0.7020 - val_vowel_output_loss: 0.1864 - val_consonant_output_loss: 0.1597
#  - root_recall: 0.7631 - vowel_recall: 0.9389 - consonant_recall: 0.9342 - final_score: 0.8498
# current epoch : 9 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 1.9361 - root_output_loss: 1.2404 - vowel_output_loss: 0.4045 - consonant_output_loss: 0.2912 - val_loss: 1.6616 - val_root_output_loss: 1.1000 - val_vowel_output_loss: 0.2583 - val_consonant_output_loss: 0.3077
#  - root_recall: 0.6523 - vowel_recall: 0.8944 - consonant_recall: 0.7546 - final_score: 0.7384
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 1.0916 - root_output_loss: 0.7188 - vowel_output_loss: 0.2019 - consonant_output_loss: 0.1710 - val_loss: 1.9411 - val_root_output_loss: 1.1056 - val_vowel_output_loss: 0.3795 - val_consonant_output_loss: 0.2714
#  - root_recall: 0.6563 - vowel_recall: 0.8296 - consonant_recall: 0.8048 - final_score: 0.7368
# Epoch 1/1
# 156/156 [==============================] - 43s 277ms/step - loss: 1.1740 - root_output_loss: 0.7847 - vowel_output_loss: 0.2114 - consonant_output_loss: 0.1779 - val_loss: 1.1802 - val_root_output_loss: 0.7939 - val_vowel_output_loss: 0.2235 - val_consonant_output_loss: 0.1832
#  - root_recall: 0.7525 - vowel_recall: 0.8987 - consonant_recall: 0.8595 - final_score: 0.8158
# Epoch 1/1
# 156/156 [==============================] - 43s 277ms/step - loss: 0.9133 - root_output_loss: 0.6002 - vowel_output_loss: 0.1654 - consonant_output_loss: 0.1477 - val_loss: 0.8800 - val_root_output_loss: 0.5492 - val_vowel_output_loss: 0.1664 - val_consonant_output_loss: 0.1465
#  - root_recall: 0.8254 - vowel_recall: 0.9289 - consonant_recall: 0.9429 - final_score: 0.8807
# current epoch : 10 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 280ms/step - loss: 0.9785 - root_output_loss: 0.6325 - vowel_output_loss: 0.1892 - consonant_output_loss: 0.1567 - val_loss: 2.8106 - val_root_output_loss: 1.1457 - val_vowel_output_loss: 0.9018 - val_consonant_output_loss: 0.2795
#  - root_recall: 0.6510 - vowel_recall: 0.7350 - consonant_recall: 0.7764 - final_score: 0.7034
# Epoch 1/1
# 156/156 [==============================] - 43s 278ms/step - loss: 1.0720 - root_output_loss: 0.6979 - vowel_output_loss: 0.2092 - consonant_output_loss: 0.1649 - val_loss: 7.3544 - val_root_output_loss: 4.7438 - val_vowel_output_loss: 1.9359 - val_consonant_output_loss: 0.9214
#  - root_recall: 0.1378 - vowel_recall: 0.4400 - consonant_recall: 0.4158 - final_score: 0.2828
# Epoch 1/1
# 156/156 [==============================] - 43s 278ms/step - loss: 1.0094 - root_output_loss: 0.6714 - vowel_output_loss: 0.1787 - consonant_output_loss: 0.1593 - val_loss: 0.9408 - val_root_output_loss: 0.7388 - val_vowel_output_loss: 0.2104 - val_consonant_output_loss: 0.1760
#  - root_recall: 0.7718 - vowel_recall: 0.9155 - consonant_recall: 0.8428 - final_score: 0.8255
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 0.7712 - root_output_loss: 0.5054 - vowel_output_loss: 0.1400 - consonant_output_loss: 0.1258 - val_loss: 0.5603 - val_root_output_loss: 0.5101 - val_vowel_output_loss: 0.1363 - val_consonant_output_loss: 0.1231
#  - root_recall: 0.8269 - vowel_recall: 0.9542 - consonant_recall: 0.9446 - final_score: 0.8881
# current epoch : 11 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 0.7585 - root_output_loss: 0.4943 - vowel_output_loss: 0.1411 - consonant_output_loss: 0.1232 - val_loss: 0.6621 - val_root_output_loss: 0.4828 - val_vowel_output_loss: 0.1399 - val_consonant_output_loss: 0.1161
#  - root_recall: 0.8262 - vowel_recall: 0.9372 - consonant_recall: 0.9309 - final_score: 0.8802
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 0.7893 - root_output_loss: 0.5133 - vowel_output_loss: 0.1492 - consonant_output_loss: 0.1268 - val_loss: 0.9513 - val_root_output_loss: 0.5480 - val_vowel_output_loss: 0.1780 - val_consonant_output_loss: 0.1492
#  - root_recall: 0.8000 - vowel_recall: 0.9253 - consonant_recall: 0.9284 - final_score: 0.8634
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 0.7086 - root_output_loss: 0.4695 - vowel_output_loss: 0.1241 - consonant_output_loss: 0.1150 - val_loss: 0.8978 - val_root_output_loss: 0.5352 - val_vowel_output_loss: 0.1985 - val_consonant_output_loss: 0.1368
#  - root_recall: 0.8041 - vowel_recall: 0.9276 - consonant_recall: 0.9055 - final_score: 0.8603
# Epoch 1/1
# 156/156 [==============================] - 43s 279ms/step - loss: 0.7391 - root_output_loss: 0.4837 - vowel_output_loss: 0.1383 - consonant_output_loss: 0.1171 - val_loss: 0.6200 - val_root_output_loss: 0.5072 - val_vowel_output_loss: 0.1527 - val_consonant_output_loss: 0.1203
#  - root_recall: 0.8350 - vowel_recall: 0.9429 - consonant_recall: 0.9264 - final_score: 0.8848
# current epoch : 12 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 0.8325 - root_output_loss: 0.5356 - vowel_output_loss: 0.1586 - consonant_output_loss: 0.1382 - val_loss: 0.7308 - val_root_output_loss: 0.5677 - val_vowel_output_loss: 0.1701 - val_consonant_output_loss: 0.1349
#  - root_recall: 0.7994 - vowel_recall: 0.9387 - consonant_recall: 0.9047 - final_score: 0.8605
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 0.6837 - root_output_loss: 0.4443 - vowel_output_loss: 0.1262 - consonant_output_loss: 0.1132 - val_loss: 0.6092 - val_root_output_loss: 0.4890 - val_vowel_output_loss: 0.1187 - val_consonant_output_loss: 0.1461
#  - root_recall: 0.8269 - vowel_recall: 0.9563 - consonant_recall: 0.9087 - final_score: 0.8797
# Epoch 1/1
# 156/156 [==============================] - 43s 278ms/step - loss: 0.7807 - root_output_loss: 0.5133 - vowel_output_loss: 0.1362 - consonant_output_loss: 0.1313 - val_loss: 2.6598 - val_root_output_loss: 1.4871 - val_vowel_output_loss: 0.4676 - val_consonant_output_loss: 0.3707
#  - root_recall: 0.6266 - vowel_recall: 0.8116 - consonant_recall: 0.7448 - final_score: 0.7024
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 0.6935 - root_output_loss: 0.4595 - vowel_output_loss: 0.1233 - consonant_output_loss: 0.1107 - val_loss: 0.8895 - val_root_output_loss: 0.4528 - val_vowel_output_loss: 0.1318 - val_consonant_output_loss: 0.1228
#  - root_recall: 0.8513 - vowel_recall: 0.9515 - consonant_recall: 0.9443 - final_score: 0.8996
# current epoch : 13 / 30
# Epoch 1/1
# 156/156 [==============================] - 43s 278ms/step - loss: 0.5990 - root_output_loss: 0.3884 - vowel_output_loss: 0.1115 - consonant_output_loss: 0.0990 - val_loss: 0.7021 - val_root_output_loss: 0.4029 - val_vowel_output_loss: 0.1175 - val_consonant_output_loss: 0.1224
#  - root_recall: 0.8557 - vowel_recall: 0.9561 - consonant_recall: 0.9141 - final_score: 0.8954
# Epoch 1/1
# 156/156 [==============================] - 43s 279ms/step - loss: 0.9053 - root_output_loss: 0.5943 - vowel_output_loss: 0.1704 - consonant_output_loss: 0.1406 - val_loss: 0.7520 - val_root_output_loss: 0.5040 - val_vowel_output_loss: 0.1399 - val_consonant_output_loss: 0.1390
#  - root_recall: 0.8276 - vowel_recall: 0.9424 - consonant_recall: 0.9357 - final_score: 0.8833
# Epoch 1/1
# 156/156 [==============================] - 43s 277ms/step - loss: 0.6655 - root_output_loss: 0.4374 - vowel_output_loss: 0.1174 - consonant_output_loss: 0.1107 - val_loss: 0.8816 - val_root_output_loss: 0.5015 - val_vowel_output_loss: 0.1452 - val_consonant_output_loss: 0.1275
#  - root_recall: 0.8249 - vowel_recall: 0.9385 - consonant_recall: 0.9061 - final_score: 0.8736
# Epoch 1/1
# 156/156 [==============================] - 43s 278ms/step - loss: 0.5797 - root_output_loss: 0.3764 - vowel_output_loss: 0.1091 - consonant_output_loss: 0.0942 - val_loss: 0.6806 - val_root_output_loss: 0.4246 - val_vowel_output_loss: 0.1237 - val_consonant_output_loss: 0.1122
#  - root_recall: 0.8542 - vowel_recall: 0.9534 - consonant_recall: 0.9545 - final_score: 0.9041
# current epoch : 14 / 30
# Epoch 1/1
# 156/156 [==============================] - 43s 279ms/step - loss: 0.5325 - root_output_loss: 0.3468 - vowel_output_loss: 0.0939 - consonant_output_loss: 0.0918 - val_loss: 0.7332 - val_root_output_loss: 0.4111 - val_vowel_output_loss: 0.1118 - val_consonant_output_loss: 0.1079
#  - root_recall: 0.8479 - vowel_recall: 0.9523 - consonant_recall: 0.9230 - final_score: 0.8928
# Epoch 1/1
# 156/156 [==============================] - 43s 278ms/step - loss: 0.7193 - root_output_loss: 0.4629 - vowel_output_loss: 0.1370 - consonant_output_loss: 0.1195 - val_loss: 1.4104 - val_root_output_loss: 0.8307 - val_vowel_output_loss: 0.2037 - val_consonant_output_loss: 0.3287
#  - root_recall: 0.7454 - vowel_recall: 0.9228 - consonant_recall: 0.8405 - final_score: 0.8135
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 0.9542 - root_output_loss: 0.6246 - vowel_output_loss: 0.1802 - consonant_output_loss: 0.1493 - val_loss: 2.1764 - val_root_output_loss: 1.0278 - val_vowel_output_loss: 0.7830 - val_consonant_output_loss: 0.3409
#  - root_recall: 0.6918 - vowel_recall: 0.7835 - consonant_recall: 0.8230 - final_score: 0.7476
# Epoch 1/1
# 156/156 [==============================] - 44s 282ms/step - loss: 0.6837 - root_output_loss: 0.4467 - vowel_output_loss: 0.1285 - consonant_output_loss: 0.1086 - val_loss: 0.8879 - val_root_output_loss: 0.4886 - val_vowel_output_loss: 0.1462 - val_consonant_output_loss: 0.1242
#  - root_recall: 0.8478 - vowel_recall: 0.9439 - consonant_recall: 0.9461 - final_score: 0.8964
# current epoch : 15 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 1.0630 - root_output_loss: 0.6889 - vowel_output_loss: 0.2143 - consonant_output_loss: 0.1598 - val_loss: 2.1999 - val_root_output_loss: 1.2468 - val_vowel_output_loss: 0.5344 - val_consonant_output_loss: 0.3202
#  - root_recall: 0.6623 - vowel_recall: 0.7699 - consonant_recall: 0.7873 - final_score: 0.7205
# Epoch 1/1
# 156/156 [==============================] - 43s 278ms/step - loss: 0.7900 - root_output_loss: 0.5131 - vowel_output_loss: 0.1504 - consonant_output_loss: 0.1265 - val_loss: 0.7548 - val_root_output_loss: 0.4742 - val_vowel_output_loss: 0.1361 - val_consonant_output_loss: 0.1179
#  - root_recall: 0.8373 - vowel_recall: 0.9466 - consonant_recall: 0.9281 - final_score: 0.8873
# Epoch 1/1
# 156/156 [==============================] - 43s 279ms/step - loss: 0.7403 - root_output_loss: 0.4790 - vowel_output_loss: 0.1446 - consonant_output_loss: 0.1168 - val_loss: 0.6946 - val_root_output_loss: 0.4648 - val_vowel_output_loss: 0.1271 - val_consonant_output_loss: 0.1331
#  - root_recall: 0.8366 - vowel_recall: 0.9508 - consonant_recall: 0.9210 - final_score: 0.8862
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 0.6137 - root_output_loss: 0.3973 - vowel_output_loss: 0.1161 - consonant_output_loss: 0.1003 - val_loss: 0.8980 - val_root_output_loss: 0.5659 - val_vowel_output_loss: 0.1552 - val_consonant_output_loss: 0.1600
#  - root_recall: 0.8293 - vowel_recall: 0.9520 - consonant_recall: 0.8994 - final_score: 0.8775
# current epoch : 16 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 282ms/step - loss: 0.6103 - root_output_loss: 0.3942 - vowel_output_loss: 0.1133 - consonant_output_loss: 0.1028 - val_loss: 0.8211 - val_root_output_loss: 0.4955 - val_vowel_output_loss: 0.1296 - val_consonant_output_loss: 0.1221
#  - root_recall: 0.8289 - vowel_recall: 0.9478 - consonant_recall: 0.9269 - final_score: 0.8832
# Epoch 1/1
# 156/156 [==============================] - 44s 283ms/step - loss: 0.5646 - root_output_loss: 0.3645 - vowel_output_loss: 0.1050 - consonant_output_loss: 0.0951 - val_loss: 0.7164 - val_root_output_loss: 0.4556 - val_vowel_output_loss: 0.1161 - val_consonant_output_loss: 0.1208
#  - root_recall: 0.8408 - vowel_recall: 0.9566 - consonant_recall: 0.9287 - final_score: 0.8917
# Epoch 1/1
# 156/156 [==============================] - 44s 282ms/step - loss: 0.5544 - root_output_loss: 0.3626 - vowel_output_loss: 0.1019 - consonant_output_loss: 0.0898 - val_loss: 1.2658 - val_root_output_loss: 0.8339 - val_vowel_output_loss: 0.3346 - val_consonant_output_loss: 0.2177
#  - root_recall: 0.7445 - vowel_recall: 0.8857 - consonant_recall: 0.8449 - final_score: 0.8049
# Epoch 1/1
# 156/156 [==============================] - 45s 286ms/step - loss: 0.5492 - root_output_loss: 0.3573 - vowel_output_loss: 0.1016 - consonant_output_loss: 0.0904 - val_loss: 0.7644 - val_root_output_loss: 0.4671 - val_vowel_output_loss: 0.1226 - val_consonant_output_loss: 0.1059
#  - root_recall: 0.8486 - vowel_recall: 0.9516 - consonant_recall: 0.9467 - final_score: 0.8989
# current epoch : 17 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 284ms/step - loss: 1.5416 - root_output_loss: 1.0170 - vowel_output_loss: 0.2911 - consonant_output_loss: 0.2335 - val_loss: 4.0364 - val_root_output_loss: 2.2377 - val_vowel_output_loss: 0.8008 - val_consonant_output_loss: 0.6966
#  - root_recall: 0.4306 - vowel_recall: 0.6655 - consonant_recall: 0.4621 - final_score: 0.4972
# Epoch 1/1
# 156/156 [==============================] - 44s 283ms/step - loss: 1.0320 - root_output_loss: 0.6816 - vowel_output_loss: 0.1889 - consonant_output_loss: 0.1616 - val_loss: 1.2455 - val_root_output_loss: 0.7125 - val_vowel_output_loss: 0.2006 - val_consonant_output_loss: 0.1783
#  - root_recall: 0.7654 - vowel_recall: 0.9079 - consonant_recall: 0.8795 - final_score: 0.8295
# Epoch 1/1
# 156/156 [==============================] - 44s 283ms/step - loss: 0.7609 - root_output_loss: 0.5033 - vowel_output_loss: 0.1356 - consonant_output_loss: 0.1220 - val_loss: 1.2139 - val_root_output_loss: 0.9193 - val_vowel_output_loss: 0.2602 - val_consonant_output_loss: 0.2465
#  - root_recall: 0.7552 - vowel_recall: 0.8980 - consonant_recall: 0.8216 - final_score: 0.8075
# Epoch 1/1
# 156/156 [==============================] - 45s 287ms/step - loss: 0.6689 - root_output_loss: 0.4355 - vowel_output_loss: 0.1254 - consonant_output_loss: 0.1081 - val_loss: 0.6794 - val_root_output_loss: 0.4550 - val_vowel_output_loss: 0.1283 - val_consonant_output_loss: 0.1200
#  - root_recall: 0.8545 - vowel_recall: 0.9543 - consonant_recall: 0.9539 - final_score: 0.9043
# current epoch : 18 / 30
# Epoch 1/1
# 156/156 [==============================] - 45s 286ms/step - loss: 0.6381 - root_output_loss: 0.4160 - vowel_output_loss: 0.1174 - consonant_output_loss: 0.1048 - val_loss: 0.8741 - val_root_output_loss: 0.5081 - val_vowel_output_loss: 0.1585 - val_consonant_output_loss: 0.1290
#  - root_recall: 0.8143 - vowel_recall: 0.9420 - consonant_recall: 0.9161 - final_score: 0.8717
# Epoch 1/1
# 156/156 [==============================] - 44s 285ms/step - loss: 0.6244 - root_output_loss: 0.4047 - vowel_output_loss: 0.1194 - consonant_output_loss: 0.1002 - val_loss: 1.4413 - val_root_output_loss: 0.7678 - val_vowel_output_loss: 0.2562 - val_consonant_output_loss: 0.2417
#  - root_recall: 0.7547 - vowel_recall: 0.8854 - consonant_recall: 0.8845 - final_score: 0.8198
# Epoch 1/1
# 156/156 [==============================] - 45s 286ms/step - loss: 0.7079 - root_output_loss: 0.4614 - vowel_output_loss: 0.1344 - consonant_output_loss: 0.1122 - val_loss: 1.5278 - val_root_output_loss: 0.8597 - val_vowel_output_loss: 0.3211 - val_consonant_output_loss: 0.1808
#  - root_recall: 0.7580 - vowel_recall: 0.8862 - consonant_recall: 0.8990 - final_score: 0.8253
# Epoch 1/1
# 156/156 [==============================] - 45s 288ms/step - loss: 0.6470 - root_output_loss: 0.4297 - vowel_output_loss: 0.1184 - consonant_output_loss: 0.0989 - val_loss: 0.6910 - val_root_output_loss: 0.5768 - val_vowel_output_loss: 0.1874 - val_consonant_output_loss: 0.1241
#  - root_recall: 0.8175 - vowel_recall: 0.9428 - consonant_recall: 0.9452 - final_score: 0.8807
# current epoch : 19 / 30
# Epoch 1/1
# 156/156 [==============================] - 45s 287ms/step - loss: 0.6364 - root_output_loss: 0.4207 - vowel_output_loss: 0.1128 - consonant_output_loss: 0.1028 - val_loss: 1.0939 - val_root_output_loss: 0.7229 - val_vowel_output_loss: 0.2125 - val_consonant_output_loss: 0.2089
#  - root_recall: 0.7636 - vowel_recall: 0.9045 - consonant_recall: 0.8507 - final_score: 0.8206
# Epoch 1/1
# 156/156 [==============================] - 45s 286ms/step - loss: 0.6427 - root_output_loss: 0.4258 - vowel_output_loss: 0.1161 - consonant_output_loss: 0.1009 - val_loss: 0.9347 - val_root_output_loss: 0.6518 - val_vowel_output_loss: 0.1562 - val_consonant_output_loss: 0.1466
#  - root_recall: 0.7735 - vowel_recall: 0.9427 - consonant_recall: 0.9182 - final_score: 0.8520
# Epoch 1/1
# 156/156 [==============================] - 45s 286ms/step - loss: 0.5324 - root_output_loss: 0.3492 - vowel_output_loss: 0.0976 - consonant_output_loss: 0.0856 - val_loss: 0.7682 - val_root_output_loss: 0.4822 - val_vowel_output_loss: 0.1285 - val_consonant_output_loss: 0.1235
#  - root_recall: 0.8477 - vowel_recall: 0.9484 - consonant_recall: 0.9238 - final_score: 0.8919
# Epoch 1/1
# 156/156 [==============================] - 45s 288ms/step - loss: 0.5355 - root_output_loss: 0.3555 - vowel_output_loss: 0.0949 - consonant_output_loss: 0.0852 - val_loss: 0.7813 - val_root_output_loss: 0.5046 - val_vowel_output_loss: 0.1346 - val_consonant_output_loss: 0.1146
#  - root_recall: 0.8351 - vowel_recall: 0.9581 - consonant_recall: 0.9566 - final_score: 0.8962
# current epoch : 20 / 30
# Epoch 1/1
# 156/156 [==============================] - 45s 286ms/step - loss: 0.5630 - root_output_loss: 0.3700 - vowel_output_loss: 0.1027 - consonant_output_loss: 0.0902 - val_loss: 1.0549 - val_root_output_loss: 0.5734 - val_vowel_output_loss: 0.1732 - val_consonant_output_loss: 0.1536
#  - root_recall: 0.8231 - vowel_recall: 0.9301 - consonant_recall: 0.9140 - final_score: 0.8726
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 0.5014 - root_output_loss: 0.3297 - vowel_output_loss: 0.0911 - consonant_output_loss: 0.0805 - val_loss: 0.5139 - val_root_output_loss: 0.3920 - val_vowel_output_loss: 0.1021 - val_consonant_output_loss: 0.1073
#  - root_recall: 0.8580 - vowel_recall: 0.9539 - consonant_recall: 0.9459 - final_score: 0.9039
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 0.5821 - root_output_loss: 0.3859 - vowel_output_loss: 0.1052 - consonant_output_loss: 0.0910 - val_loss: 2.2930 - val_root_output_loss: 1.4366 - val_vowel_output_loss: 0.4721 - val_consonant_output_loss: 0.2603
#  - root_recall: 0.6036 - vowel_recall: 0.8377 - consonant_recall: 0.8631 - final_score: 0.7270
# Epoch 1/1
# 156/156 [==============================] - 44s 282ms/step - loss: 0.7203 - root_output_loss: 0.4715 - vowel_output_loss: 0.1355 - consonant_output_loss: 0.1133 - val_loss: 3.2049 - val_root_output_loss: 2.2228 - val_vowel_output_loss: 1.2955 - val_consonant_output_loss: 0.4040
#  - root_recall: 0.5633 - vowel_recall: 0.8134 - consonant_recall: 0.8516 - final_score: 0.6979
# current epoch : 21 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 282ms/step - loss: 0.6560 - root_output_loss: 0.4415 - vowel_output_loss: 0.1147 - consonant_output_loss: 0.0999 - val_loss: 0.6921 - val_root_output_loss: 0.3923 - val_vowel_output_loss: 0.1079 - val_consonant_output_loss: 0.1091
#  - root_recall: 0.8637 - vowel_recall: 0.9631 - consonant_recall: 0.9358 - final_score: 0.9066
# Epoch 1/1
# 156/156 [==============================] - 44s 285ms/step - loss: 0.4919 - root_output_loss: 0.3280 - vowel_output_loss: 0.0854 - consonant_output_loss: 0.0785 - val_loss: 0.6632 - val_root_output_loss: 0.4153 - val_vowel_output_loss: 0.1086 - val_consonant_output_loss: 0.1049
#  - root_recall: 0.8601 - vowel_recall: 0.9639 - consonant_recall: 0.9435 - final_score: 0.9069
# Epoch 1/1
# 156/156 [==============================] - 45s 288ms/step - loss: 0.4227 - root_output_loss: 0.2829 - vowel_output_loss: 0.0714 - consonant_output_loss: 0.0683 - val_loss: 0.7955 - val_root_output_loss: 0.5027 - val_vowel_output_loss: 0.1441 - val_consonant_output_loss: 0.1291
#  - root_recall: 0.8447 - vowel_recall: 0.9476 - consonant_recall: 0.9068 - final_score: 0.8859
# Epoch 1/1
# 156/156 [==============================] - 45s 291ms/step - loss: 0.4369 - root_output_loss: 0.2914 - vowel_output_loss: 0.0767 - consonant_output_loss: 0.0688 - val_loss: 0.7748 - val_root_output_loss: 0.4020 - val_vowel_output_loss: 0.1209 - val_consonant_output_loss: 0.1017
#  - root_recall: 0.8684 - vowel_recall: 0.9579 - consonant_recall: 0.9648 - final_score: 0.9149
# current epoch : 22 / 30
# Epoch 1/1
# 156/156 [==============================] - 46s 292ms/step - loss: 0.5108 - root_output_loss: 0.3340 - vowel_output_loss: 0.0920 - consonant_output_loss: 0.0848 - val_loss: 1.0885 - val_root_output_loss: 0.6363 - val_vowel_output_loss: 0.2087 - val_consonant_output_loss: 0.1907
#  - root_recall: 0.8257 - vowel_recall: 0.9321 - consonant_recall: 0.8421 - final_score: 0.8564
# Epoch 1/1
# 156/156 [==============================] - 46s 292ms/step - loss: 0.6936 - root_output_loss: 0.4460 - vowel_output_loss: 0.1364 - consonant_output_loss: 0.1113 - val_loss: 0.6507 - val_root_output_loss: 0.4971 - val_vowel_output_loss: 0.1378 - val_consonant_output_loss: 0.1282
#  - root_recall: 0.8373 - vowel_recall: 0.9506 - consonant_recall: 0.9305 - final_score: 0.8889
# Epoch 1/1
# 156/156 [==============================] - 46s 292ms/step - loss: 0.5244 - root_output_loss: 0.3419 - vowel_output_loss: 0.0992 - consonant_output_loss: 0.0832 - val_loss: 0.8100 - val_root_output_loss: 0.4357 - val_vowel_output_loss: 0.1239 - val_consonant_output_loss: 0.1151
#  - root_recall: 0.8493 - vowel_recall: 0.9482 - consonant_recall: 0.9315 - final_score: 0.8946
# Epoch 1/1
# 156/156 [==============================] - 45s 289ms/step - loss: 0.4656 - root_output_loss: 0.3053 - vowel_output_loss: 0.0895 - consonant_output_loss: 0.0709 - val_loss: 0.6903 - val_root_output_loss: 0.4452 - val_vowel_output_loss: 0.1230 - val_consonant_output_loss: 0.1019
#  - root_recall: 0.8535 - vowel_recall: 0.9516 - consonant_recall: 0.9543 - final_score: 0.9032
# current epoch : 23 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 284ms/step - loss: 0.4209 - root_output_loss: 0.2710 - vowel_output_loss: 0.0817 - consonant_output_loss: 0.0683 - val_loss: 0.5096 - val_root_output_loss: 0.3687 - val_vowel_output_loss: 0.1119 - val_consonant_output_loss: 0.1012
#  - root_recall: 0.8726 - vowel_recall: 0.9586 - consonant_recall: 0.9377 - final_score: 0.9104
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 0.3986 - root_output_loss: 0.2568 - vowel_output_loss: 0.0747 - consonant_output_loss: 0.0671 - val_loss: 0.4740 - val_root_output_loss: 0.3545 - val_vowel_output_loss: 0.1017 - val_consonant_output_loss: 0.1096
#  - root_recall: 0.8762 - vowel_recall: 0.9575 - consonant_recall: 0.9432 - final_score: 0.9133
# Epoch 1/1
# 156/156 [==============================] - 44s 281ms/step - loss: 0.8036 - root_output_loss: 0.5285 - vowel_output_loss: 0.1567 - consonant_output_loss: 0.1184 - val_loss: 2.1214 - val_root_output_loss: 1.2602 - val_vowel_output_loss: 0.6945 - val_consonant_output_loss: 0.3070
#  - root_recall: 0.6486 - vowel_recall: 0.7768 - consonant_recall: 0.8440 - final_score: 0.7295
# Epoch 1/1
# 156/156 [==============================] - 44s 279ms/step - loss: 0.6902 - root_output_loss: 0.4592 - vowel_output_loss: 0.1284 - consonant_output_loss: 0.1027 - val_loss: 0.7369 - val_root_output_loss: 0.5118 - val_vowel_output_loss: 0.1536 - val_consonant_output_loss: 0.1253
#  - root_recall: 0.8455 - vowel_recall: 0.9456 - consonant_recall: 0.9293 - final_score: 0.8915
# current epoch : 24 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 280ms/step - loss: 0.4763 - root_output_loss: 0.3115 - vowel_output_loss: 0.0879 - consonant_output_loss: 0.0769 - val_loss: 0.6113 - val_root_output_loss: 0.3732 - val_vowel_output_loss: 0.1107 - val_consonant_output_loss: 0.1017
#  - root_recall: 0.8744 - vowel_recall: 0.9630 - consonant_recall: 0.9423 - final_score: 0.9135
# Epoch 1/1
# 156/156 [==============================] - 43s 278ms/step - loss: 0.4741 - root_output_loss: 0.3074 - vowel_output_loss: 0.0912 - consonant_output_loss: 0.0755 - val_loss: 0.6706 - val_root_output_loss: 0.3954 - val_vowel_output_loss: 0.1089 - val_consonant_output_loss: 0.1140
#  - root_recall: 0.8657 - vowel_recall: 0.9573 - consonant_recall: 0.9431 - final_score: 0.9080
# Epoch 1/1
# 156/156 [==============================] - 45s 290ms/step - loss: 0.4310 - root_output_loss: 0.2745 - vowel_output_loss: 0.0823 - consonant_output_loss: 0.0742 - val_loss: 0.7539 - val_root_output_loss: 0.4365 - val_vowel_output_loss: 0.1133 - val_consonant_output_loss: 0.1216
#  - root_recall: 0.8567 - vowel_recall: 0.9560 - consonant_recall: 0.9043 - final_score: 0.8934
# Epoch 1/1
# 156/156 [==============================] - 45s 289ms/step - loss: 0.4042 - root_output_loss: 0.2579 - vowel_output_loss: 0.0777 - consonant_output_loss: 0.0686 - val_loss: 0.5433 - val_root_output_loss: 0.3806 - val_vowel_output_loss: 0.1181 - val_consonant_output_loss: 0.0990
#  - root_recall: 0.8850 - vowel_recall: 0.9572 - consonant_recall: 0.9603 - final_score: 0.9219
# current epoch : 29 / 30
# Epoch 1/1
# 156/156 [==============================] - 44s 284ms/step - loss: 0.3660 - root_output_loss: 0.2325 - vowel_output_loss: 0.0698 - consonant_output_loss: 0.0636 - val_loss: 0.4890 - val_root_output_loss: 0.3866 - val_vowel_output_loss: 0.1277 - val_consonant_output_loss: 0.1030
#  - root_recall: 0.8695 - vowel_recall: 0.9489 - consonant_recall: 0.9537 - final_score: 0.9104
# Epoch 1/1
# 156/156 [==============================] - 45s 289ms/step - loss: 0.4154 - root_output_loss: 0.2702 - vowel_output_loss: 0.0746 - consonant_output_loss: 0.0705 - val_loss: 0.6101 - val_root_output_loss: 0.3869 - val_vowel_output_loss: 0.1092 - val_consonant_output_loss: 0.1095
#  - root_recall: 0.8800 - vowel_recall: 0.9644 - consonant_recall: 0.9397 - final_score: 0.9160
# Epoch 1/1
# 156/156 [==============================] - 45s 287ms/step - loss: 0.3697 - root_output_loss: 0.2317 - vowel_output_loss: 0.0762 - consonant_output_loss: 0.0618 - val_loss: 1.0978 - val_root_output_loss: 0.6548 - val_vowel_output_loss: 0.2550 - val_consonant_output_loss: 0.1474
#  - root_recall: 0.7942 - vowel_recall: 0.9339 - consonant_recall: 0.9421 - final_score: 0.8661

# %%
trained_model.save('inception_V3.h5')

# %%
results_df = pd.DataFrame(columns=['val_loss', 'val_root_output_loss', 'val_vowel_output_loss',
                                   'val_consonant_output_loss', 'loss', 'root_output_loss',
                                   'vowel_output_loss', 'consonant_output_loss', 'root_recall',
                                   'vowel_recall', 'consonant_recall', 'final_score'])
for hist in history:
    results_df = results_df.append(pd.DataFrame(hist), ignore_index=True)

# %%
display(results_df)
# Out:
#       val_loss  val_root_output_loss  val_vowel_output_loss  \
# 0     8.454908              4.773152               2.486796
# 1    11.682428              6.737062               2.938122
# 2     7.767509              5.158308               1.221524
# 3     5.815256              4.167014               0.781192
# 4     4.201286              3.317070               0.531095
# ..         ...                   ...                    ...
# 115   1.015520              0.631990               0.179472
# 116   0.715898              0.462170               0.131645
# 117   0.892650              0.607110               0.191676
# 118   0.610078              0.386863               0.109248
# 119   1.097831              0.654833               0.255010
#
#      val_consonant_output_loss      loss  root_output_loss  vowel_output_loss  \
# 0                     1.240793  7.433312          4.706974           1.635130
# 1                     2.024925  6.202181          4.329423           0.964232
# 2                     1.117888  5.432992          3.967732           0.732046
# 3                     0.715859  4.726398          3.571290           0.579952
# 4                     0.447496  4.127254          3.142641           0.501024
# ..                         ...       ...               ...                ...
# 115                   0.153720  0.391498          0.249230           0.075714
# 116                   0.129927  0.637558          0.398630           0.132506
# 117                   0.167489  0.435384          0.273507           0.085952
# 118                   0.109516  0.415356          0.270234           0.074641
# 119                   0.147448  0.369690          0.231748           0.076160
#
#      consonant_output_loss  root_recall  vowel_recall  consonant_recall  \
# 0                 1.091209     0.006042      0.091630          0.142857
# 1                 0.908528     0.007880      0.203344          0.238492
# 2                 0.733215     0.016381      0.515274          0.361758
# 3                 0.575155     0.062129      0.656555          0.529470
# 4                 0.483589     0.136643      0.756235          0.691402
# ..                     ...          ...           ...               ...
# 115               0.066554     0.820444      0.936217          0.913322
# 116               0.106422     0.848585      0.946177          0.939012
# 117               0.075925     0.812072      0.922422          0.907321
# 118               0.070480     0.879997      0.964370          0.939690
# 119               0.061782     0.794187      0.933926          0.942096
#
#      final_score
# 0       0.061643
# 1       0.114399
# 2       0.227449
# 3       0.327571
# 4       0.430230
# ..           ...
# 115     0.872607
# 116     0.895590
# 117     0.863472
# 118     0.916013
# 119     0.866099
#
# [120 rows x 12 columns]

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax = sns.lineplot(data=results_df.loc[:,['root_recall', 'vowel_recall', 
                                         'consonant_recall', 'final_score']], linestyle=None)
ax.set_xlabel('epochs', labelpad=15, fontsize=15)
ax.set_ylabel('score', labelpad=15, fontsize=15)
ax.set_title('Validation scores', pad=15, fontsize=20)
plt.xticks(np.arange(0,results_df.shape[0],4))
plt.yticks(np.arange(0,1.1,0.1))
ax.grid(axis='both', linestyle=':', linewidth=1)

# %%
fig, ax1 = plt.subplots(figsize=(10,8))
ax1 = sns.lineplot(data=results_df.loc[:,['val_loss', 'val_root_output_loss', 'val_vowel_output_loss',
                                          'val_consonant_output_loss']], linestyle=None)
ax1.set_xlabel('epochs', labelpad=15, fontsize=15)
ax1.set_ylabel('loss', labelpad=15, fontsize=15)
ax1.set_title('Validation losses', pad=15, fontsize=20)
plt.xticks(np.arange(0,results_df.shape[0],4))
ax1.grid(axis='both', linestyle=':', linewidth=1)

# %%
fig, ax2 = plt.subplots(figsize=(10,8))
ax2 = sns.lineplot(data=results_df.loc[:,['loss', 'root_output_loss','vowel_output_loss', 
                                          'consonant_output_loss']], linestyle=None)
ax2.set_xlabel('epochs', labelpad=15, fontsize=15)
ax2.set_ylabel('loss', labelpad=15, fontsize=15)
ax2.set_title('Training losses', pad=15, fontsize=20)
plt.xticks(np.arange(0,results_df.shape[0],4))
ax2.grid(axis='both', linestyle=':', linewidth=1)
