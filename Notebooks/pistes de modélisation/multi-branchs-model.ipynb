# %%
import gc
import time
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score

from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input, AveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import Callback

from keras.utils import plot_model
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# /kaggle/input/bengali-graphemes-croppedresized-100x100-train/train_data_0.feather
# /kaggle/input/bengali-graphemes-croppedresized-100x100-train/train_data_1.feather
# /kaggle/input/bengali-graphemes-croppedresized-100x100-train/train_data_2.feather
# /kaggle/input/bengali-graphemes-croppedresized-100x100-train/train_data_3.feather
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/train.csv

# %%
train_target = pd.read_csv('/kaggle/input/bengaliai-cv19/train.csv', index_col='image_id')

# %%
rootLB = LabelBinarizer()
vowelLB = LabelBinarizer()
consonantLB = LabelBinarizer()
rootLB.fit(train_target['grapheme_root'])
vowelLB.fit(train_target['vowel_diacritic'])
consonantLB.fit(train_target['consonant_diacritic'])
# Out:
# LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)

# %% [markdown]
# # Custom modules

# %% [markdown]
# ## Custom metric callback

# %%
class validation_recall(keras.callbacks.Callback):
    
    def __init__(self, validation_data=()):
        super(keras.callbacks.Callback, self).__init__()
        self.X_val, self.y_val = validation_data
    
    def on_epoch_end(self, epoch, logs={}):

        root_val = self.y_val[0]
        vowel_val = self.y_val[1]
        consonant_val = self.y_val[2]
        
        # Predictions on validation set for the 3 targets 
        #(+ one hot encoding)
        preds = self.model.predict(self.X_val)
        root_preds = np.zeros_like(preds[0])
        root_preds[np.arange(len(preds[0])), 
                   preds[0].argmax(axis=1)] = 1
        vowel_preds = np.zeros_like(preds[1])
        vowel_preds[np.arange(len(preds[1])), 
                    preds[1].argmax(axis=1)] = 1
        consonant_preds = np.zeros_like(preds[2])
        consonant_preds[np.arange(len(preds[2])), 
                        preds[2].argmax(axis=1)] = 1
        
        # Recall calculation for the 3 targets
        root_recall = recall_score(root_val, root_preds, 
                                   average='macro')
        vowel_recall = recall_score(vowel_val, vowel_preds, 
                                    average='macro')
        consonant_recall = recall_score(consonant_val, consonant_preds, 
                                        average='macro')
        final_score = np.average([root_recall, vowel_recall, 
                                  consonant_recall], weights=[2,1,1])
        
        # Displaying scores at the end of each epoch
        print(' - root_recall: {0:.4f}'.format(root_recall)+\
              ' - vowel_recall: {0:.4f}'.format(vowel_recall)+\
              ' - consonant_recall: {0:.4f}'.format(consonant_recall)+\
              ' - final_score: {0:.4f}'.format(final_score))

        # Saving scores in logs history
        logs['root_recall'] = root_recall
        logs['vowel_recall'] = vowel_recall
        logs['consonant_recall'] = consonant_recall
        logs['final_score'] = final_score
        
        del root_val
        del vowel_val
        del consonant_val
        del preds 
        del root_preds 
        del vowel_preds
        del consonant_preds
        gc.collect()

# %% [markdown]
# ## Custom data loader

# %% [markdown]
# Keras DataGenerator modified for multi-outputs model taken from [this very interesting notebook](https://www.kaggle.com/kaushal2896/bengali-graphemes-starter-eda-multi-output-cnn#Basic-Model) from Kaushal Shah. It will allow to generate a batch of data to feed the model while training to avoid memory shortage.

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, 
                                         batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %% [markdown]
# # Model definition

# %%
def create_root_branch(inputs):
    
    x = Conv2D(32, (3, 3), padding="same", activation='relu')(inputs)
    x = Conv2D(32, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(32, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    #x = Dropout(0.25)(x)
    
    x = Conv2D(64, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(64, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(64, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    #x = Dropout(0.25)(x)
    
    x = Conv2D(128, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(128, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(128, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    #x = Dropout(0.25)(x)
    
    x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = AveragePooling2D(pool_size=(3, 3), padding='valid')(x)
    #x = MaxPool2D(pool_size=(2, 2))(x)
    
    x = Flatten()(x)
    x = Dense(1024, activation = "relu")(x)
    x = Dropout(rate=0.3)(x)
    x = Dense(512, activation = "relu")(x)
    x = Dropout(rate=0.3)(x)
    
    root_out = Dense(168, activation='softmax', name='root_output')(x)
    #vowel_out = Dense(11, activation='softmax', name='vowel_output')(x)
    #consonant_out = Dense(7, activation='softmax', name='consonant_output')(x)

    #model = Model(inputs=inputs, outputs=[root_out, vowel_out, consonant_out])
    
    return root_out

# %%
def create_vowel_branch(inputs):
    
    x = Conv2D(32, (3, 3), padding="same", activation='relu')(inputs)
    x = Conv2D(32, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(32, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    #x = Dropout(0.25)(x)
    
    x = Conv2D(64, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(64, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(64, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    #x = Dropout(0.25)(x)
    
    x = Conv2D(128, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(128, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(128, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    #x = Dropout(0.25)(x)
    
    x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = AveragePooling2D(pool_size=(3, 3), padding='valid')(x)
    #x = MaxPool2D(pool_size=(2, 2))(x)
    
    x = Flatten()(x)
    x = Dense(1024, activation = "relu")(x)
    x = Dropout(rate=0.3)(x)
    x = Dense(512, activation = "relu")(x)
    x = Dropout(rate=0.3)(x)
    
    #root_out = Dense(168, activation='softmax', name='root_output')(x)
    vowel_out = Dense(11, activation='softmax', name='vowel_output')(x)
    #consonant_out = Dense(7, activation='softmax', name='consonant_output')(x)

    #model = Model(inputs=inputs, outputs=[root_out, vowel_out, consonant_out])
    
    return vowel_out

# %%
def create_consonant_branch(inputs):
    
    x = Conv2D(32, (3, 3), padding="same", activation='relu')(inputs)
    x = Conv2D(32, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(32, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    #x = Dropout(0.25)(x)
    
    x = Conv2D(64, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(64, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(64, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    #x = Dropout(0.25)(x)
    
    x = Conv2D(128, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(128, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(128, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    #x = Dropout(0.25)(x)
    
    x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
    x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
    x = BatchNormalization()(x)
    x = AveragePooling2D(pool_size=(3, 3), padding='valid')(x)
    #x = MaxPool2D(pool_size=(2, 2))(x)
    
    x = Flatten()(x)
    x = Dense(1024, activation = "relu")(x)
    x = Dropout(rate=0.3)(x)
    x = Dense(512, activation = "relu")(x)
    x = Dropout(rate=0.3)(x)
    
    #root_out = Dense(168, activation='softmax', name='root_output')(x)
    #vowel_out = Dense(11, activation='softmax', name='vowel_output')(x)
    consonant_out = Dense(7, activation='softmax', name='consonant_output')(x)

    #model = Model(inputs=inputs, outputs=[root_out, vowel_out, consonant_out])
    
    return consonant_out

# %%
def create_model():
    
    inputs = Input(shape=(80,80,1))
    root_branch = create_root_branch(inputs)
    vowel_branch = create_vowel_branch(inputs)
    consonant_branch = create_consonant_branch(inputs)
    model = Model(inputs=inputs, outputs=[root_branch, vowel_branch, consonant_branch])
    
    return model

# %% [markdown]
# # Training function :

# %% [markdown]
# This training function is using the following process :
# * Loading a set of images and targets data (from one of the four images files)
# * Reshape images data to numpy array with correct dimensions (100 x 100)
# * One hot encoding of the 3 targets
# * Separate all sets in two : training set and validation set
# * Creating Keras data generators to load data batch by batch in the model
# * Train the model

# %%
def train_model(model, epochs, batch_size):
    complete_history = []
    for i in range(4):

        # Images + targets loading and merging
        train_data = pd.read_feather('/kaggle/input/bengali-graphemes-'
                                     'croppedresized-100x100-train/'
                                     f'train_data_{i}.feather')
        train_data.set_index(keys=['image_id'], drop=True, inplace=True)
        train_df = pd.merge(train_data, train_target, 
                            on='image_id').drop(['grapheme'], axis=1)
        
        # Deleting previous variables to free up memory
        del train_data
        gc.collect()
        
        # One hot encoding the 3 targets with sklearn LabelBinarizer
        #rootLB = LabelBinarizer()
        #vowelLB = LabelBinarizer()
        #consonantLB = LabelBinarizer()
        rootLabels = rootLB.transform(train_df['grapheme_root'])
        vowelLabels = vowelLB.transform(train_df['vowel_diacritic'])
        consonantLabels = consonantLB.transform(
                          train_df['consonant_diacritic'])

        # Reshape images data to numpy array with same dimensions 
        # as images (80 x 80)
        train_df.drop(['grapheme_root', 'vowel_diacritic', 
                       'consonant_diacritic'], axis=1, inplace=True)
        train_df = train_df / 255
        train_images = train_df.values.reshape(-1, 80, 80, 1)
        
        # Deleting previous variables to free up memory
        del train_df
        gc.collect()

        # Creating Train / validation set for images and 3 targets
        X_train, X_val, y_train_root, y_val_root, y_train_vowel, \
        y_val_vowel, y_train_consonant, y_val_consonant \
        = train_test_split(train_images, rootLabels, vowelLabels, 
                           consonantLabels, test_size=0.1, 
                           random_state=42)
        
        # Deleting previous variables to free up memory
        del train_images
        del rootLabels, vowelLabels, consonantLabels
        gc.collect()

        # Creation of Keras Datagenerator configuration 
        # without data augmentation
        datagen = MultiOutputDataGenerator(
        featurewise_center=False,  
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range=0,
        zoom_range=0,
        width_shift_range=0,
        height_shift_range=0,
        horizontal_flip=False,
        vertical_flip=False)

        ''' You can use this piece of code to have insight of how the 
            datagen works and how batch are structured

        i = 0
        for batch in datagen.flow(X_train, 
                                 {'root': y_train_root, 
                                 'vowel': y_train_vowel, 
                                 'consonant': y_train_consonant},
                                  batch_size=1, save_to_dir=None):
            print(i)
            print('batch infos :')
            print(f'type : {type(batch)}')
            print(f'length type : {len(batch)}')
            print('features infos :')
            print(f'type : {type(batch[0])}')
            print(f'shape : {batch[0].shape}')
            print('Target infos :')
            print(f' global type : {type(batch[1])}')
            print(f'global shape : {len(batch[1])}')
            print(f'first target shape : {batch[1]["root"].shape}')
            print(f'second target shape : {batch[1]["vowel"].shape}')
            print(f'third target shape : {batch[1]["consonant"].shape}')

            i += 1
            if i > 5:
                break  # otherwise the generator would loop indefinitely

        '''
        # creation of data generator for training set
        train_generator = datagen.flow(X_train,
                                       {'root_output': y_train_root, 
                                        'vowel_output': y_train_vowel, 
                                        'consonant_output': y_train_consonant},
                                       batch_size=batch_size)
        
        # creation of data generator for validation set
        val_generator = datagen.flow(X_val,
                                     {'root_output': y_val_root, 
                                      'vowel_output': y_val_vowel, 
                                      'consonant_output': y_val_consonant},
                                     batch_size=batch_size)
        
        # Creation of callback for metric calculation
        # after each epoch
        my_call = validation_recall(validation_data=(X_val,
                                                     [y_val_root,
                                                      y_val_vowel, 
                                                      y_val_consonant]))
        
        # Model training
        history = model.fit_generator(
                train_generator,
                steps_per_epoch=X_train.shape[0] // batch_size,
                epochs=epochs,
                validation_data=val_generator,
                validation_steps=X_val.shape[0] // batch_size,
                callbacks=[my_call])
        
        # Appending training history to the one of previous
        complete_history.append(history.history)
        
        del train_generator
        del val_generator
        del my_call
        del X_train
        del X_val
        del y_train_root
        del y_val_root
        del y_train_vowel
        del y_val_vowel
        del y_train_consonant
        del y_val_consonant
        gc.collect()
        
        #time.sleep(10)
        
    return model, complete_history

# %% [markdown]
# # Model training

# %%
model = create_model()

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', 
              metrics=None)

# %%
trained_model, history = train_model(model=model, epochs=20, 
                                     batch_size=256)
# Out:
# Epoch 1/20
# 176/176 [==============================] - 109s 619ms/step - loss: 5.0781 - root_output_loss: 3.7781 - vowel_output_loss: 0.6621 - consonant_output_loss: 0.6379 - val_loss: 12.4517 - val_root_output_loss: 7.9826 - val_vowel_output_loss: 2.3344 - val_consonant_output_loss: 2.2744
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#  - root_recall: 0.0073 - vowel_recall: 0.1192 - consonant_recall: 0.1842 - final_score: 0.0795
# Epoch 2/20
# 176/176 [==============================] - 98s 557ms/step - loss: 2.2923 - root_output_loss: 1.6845 - vowel_output_loss: 0.3020 - consonant_output_loss: 0.3058 - val_loss: 7.8717 - val_root_output_loss: 5.8940 - val_vowel_output_loss: 1.0358 - val_consonant_output_loss: 1.1911
#  - root_recall: 0.0420 - vowel_recall: 0.4357 - consonant_recall: 0.4564 - final_score: 0.2440
# Epoch 3/20
# 176/176 [==============================] - 97s 552ms/step - loss: 1.3332 - root_output_loss: 0.8924 - vowel_output_loss: 0.2180 - consonant_output_loss: 0.2228 - val_loss: 3.3164 - val_root_output_loss: 2.4925 - val_vowel_output_loss: 0.3530 - val_consonant_output_loss: 0.5073
#  - root_recall: 0.4063 - vowel_recall: 0.8066 - consonant_recall: 0.5548 - final_score: 0.5435
# Epoch 4/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.9454 - root_output_loss: 0.5938 - vowel_output_loss: 0.1704 - consonant_output_loss: 0.1813 - val_loss: 1.5556 - val_root_output_loss: 0.9127 - val_vowel_output_loss: 0.2244 - val_consonant_output_loss: 0.2308
#  - root_recall: 0.7277 - vowel_recall: 0.9042 - consonant_recall: 0.8328 - final_score: 0.7981
# Epoch 5/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.7198 - root_output_loss: 0.4331 - vowel_output_loss: 0.1414 - consonant_output_loss: 0.1452 - val_loss: 0.9609 - val_root_output_loss: 0.5472 - val_vowel_output_loss: 0.1907 - val_consonant_output_loss: 0.2073
#  - root_recall: 0.8097 - vowel_recall: 0.9271 - consonant_recall: 0.8538 - final_score: 0.8501
# Epoch 6/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.5707 - root_output_loss: 0.3369 - vowel_output_loss: 0.1120 - consonant_output_loss: 0.1219 - val_loss: 0.9153 - val_root_output_loss: 0.5718 - val_vowel_output_loss: 0.2481 - val_consonant_output_loss: 0.2425
#  - root_recall: 0.7883 - vowel_recall: 0.9115 - consonant_recall: 0.8266 - final_score: 0.8287
# Epoch 7/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.4591 - root_output_loss: 0.2635 - vowel_output_loss: 0.0934 - consonant_output_loss: 0.1022 - val_loss: 0.9789 - val_root_output_loss: 0.5621 - val_vowel_output_loss: 0.2296 - val_consonant_output_loss: 0.2605
#  - root_recall: 0.8053 - vowel_recall: 0.9066 - consonant_recall: 0.8039 - final_score: 0.8302
# Epoch 8/20
# 176/176 [==============================] - 97s 550ms/step - loss: 0.3728 - root_output_loss: 0.2131 - vowel_output_loss: 0.0758 - consonant_output_loss: 0.0839 - val_loss: 1.6071 - val_root_output_loss: 0.9107 - val_vowel_output_loss: 0.3509 - val_consonant_output_loss: 0.2213
#  - root_recall: 0.7305 - vowel_recall: 0.8830 - consonant_recall: 0.8827 - final_score: 0.8067
# Epoch 9/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.3201 - root_output_loss: 0.1834 - vowel_output_loss: 0.0695 - consonant_output_loss: 0.0671 - val_loss: 1.2528 - val_root_output_loss: 0.6211 - val_vowel_output_loss: 0.2119 - val_consonant_output_loss: 0.3540
#  - root_recall: 0.8062 - vowel_recall: 0.9283 - consonant_recall: 0.7954 - final_score: 0.8340
# Epoch 10/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.2831 - root_output_loss: 0.1635 - vowel_output_loss: 0.0569 - consonant_output_loss: 0.0627 - val_loss: 1.1266 - val_root_output_loss: 0.5249 - val_vowel_output_loss: 0.2305 - val_consonant_output_loss: 0.3885
#  - root_recall: 0.8397 - vowel_recall: 0.9291 - consonant_recall: 0.7905 - final_score: 0.8497
# Epoch 11/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.2387 - root_output_loss: 0.1395 - vowel_output_loss: 0.0442 - consonant_output_loss: 0.0550 - val_loss: 1.1326 - val_root_output_loss: 0.5923 - val_vowel_output_loss: 0.3694 - val_consonant_output_loss: 0.2389
#  - root_recall: 0.8120 - vowel_recall: 0.8781 - consonant_recall: 0.8215 - final_score: 0.8309
# Epoch 12/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.2178 - root_output_loss: 0.1252 - vowel_output_loss: 0.0477 - consonant_output_loss: 0.0449 - val_loss: 1.0755 - val_root_output_loss: 0.6300 - val_vowel_output_loss: 0.2057 - val_consonant_output_loss: 0.2425
#  - root_recall: 0.8073 - vowel_recall: 0.9258 - consonant_recall: 0.8554 - final_score: 0.8489
# Epoch 13/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1930 - root_output_loss: 0.1131 - vowel_output_loss: 0.0401 - consonant_output_loss: 0.0398 - val_loss: 1.0767 - val_root_output_loss: 0.6743 - val_vowel_output_loss: 0.1590 - val_consonant_output_loss: 0.2687
#  - root_recall: 0.8120 - vowel_recall: 0.9336 - consonant_recall: 0.8655 - final_score: 0.8557
# Epoch 14/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1771 - root_output_loss: 0.1057 - vowel_output_loss: 0.0371 - consonant_output_loss: 0.0343 - val_loss: 1.4813 - val_root_output_loss: 0.7252 - val_vowel_output_loss: 0.2870 - val_consonant_output_loss: 0.2759
#  - root_recall: 0.7927 - vowel_recall: 0.9285 - consonant_recall: 0.8697 - final_score: 0.8459
# Epoch 15/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1667 - root_output_loss: 0.0973 - vowel_output_loss: 0.0345 - consonant_output_loss: 0.0348 - val_loss: 1.1071 - val_root_output_loss: 0.6327 - val_vowel_output_loss: 0.1991 - val_consonant_output_loss: 0.2299
#  - root_recall: 0.8313 - vowel_recall: 0.9333 - consonant_recall: 0.8616 - final_score: 0.8644
# Epoch 16/20
# 176/176 [==============================] - 97s 550ms/step - loss: 0.1507 - root_output_loss: 0.0908 - vowel_output_loss: 0.0279 - consonant_output_loss: 0.0320 - val_loss: 1.6432 - val_root_output_loss: 0.7024 - val_vowel_output_loss: 0.2565 - val_consonant_output_loss: 0.2990
#  - root_recall: 0.8189 - vowel_recall: 0.9305 - consonant_recall: 0.8354 - final_score: 0.8509
# Epoch 17/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1519 - root_output_loss: 0.0871 - vowel_output_loss: 0.0339 - consonant_output_loss: 0.0309 - val_loss: 2.0917 - val_root_output_loss: 1.8853 - val_vowel_output_loss: 0.2464 - val_consonant_output_loss: 0.2789
#  - root_recall: 0.6406 - vowel_recall: 0.9170 - consonant_recall: 0.8642 - final_score: 0.7656
# Epoch 18/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1322 - root_output_loss: 0.0799 - vowel_output_loss: 0.0231 - consonant_output_loss: 0.0292 - val_loss: 0.9675 - val_root_output_loss: 0.6669 - val_vowel_output_loss: 0.2298 - val_consonant_output_loss: 0.2491
#  - root_recall: 0.8181 - vowel_recall: 0.9264 - consonant_recall: 0.8787 - final_score: 0.8603
# Epoch 19/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1403 - root_output_loss: 0.0805 - vowel_output_loss: 0.0313 - consonant_output_loss: 0.0285 - val_loss: 1.3253 - val_root_output_loss: 0.7655 - val_vowel_output_loss: 0.2518 - val_consonant_output_loss: 0.2605
#  - root_recall: 0.8135 - vowel_recall: 0.9127 - consonant_recall: 0.8744 - final_score: 0.8535
# Epoch 20/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1290 - root_output_loss: 0.0885 - vowel_output_loss: 0.0232 - consonant_output_loss: 0.0174 - val_loss: 1.5807 - val_root_output_loss: 0.6380 - val_vowel_output_loss: 0.3352 - val_consonant_output_loss: 0.3514
#  - root_recall: 0.8332 - vowel_recall: 0.8912 - consonant_recall: 0.8248 - final_score: 0.8456
# Epoch 1/20
# 176/176 [==============================] - 98s 558ms/step - loss: 0.9271 - root_output_loss: 0.5707 - vowel_output_loss: 0.1816 - consonant_output_loss: 0.1749 - val_loss: 0.8220 - val_root_output_loss: 0.4509 - val_vowel_output_loss: 0.2937 - val_consonant_output_loss: 0.1817
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#  - root_recall: 0.8425 - vowel_recall: 0.8706 - consonant_recall: 0.8749 - final_score: 0.8576
# Epoch 2/20
# 176/176 [==============================] - 97s 553ms/step - loss: 0.4938 - root_output_loss: 0.3025 - vowel_output_loss: 0.0933 - consonant_output_loss: 0.0979 - val_loss: 0.9804 - val_root_output_loss: 0.5819 - val_vowel_output_loss: 0.1489 - val_consonant_output_loss: 0.2081
#  - root_recall: 0.8233 - vowel_recall: 0.9399 - consonant_recall: 0.8559 - final_score: 0.8606
# Epoch 3/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.3277 - root_output_loss: 0.2023 - vowel_output_loss: 0.0620 - consonant_output_loss: 0.0635 - val_loss: 0.8175 - val_root_output_loss: 0.4317 - val_vowel_output_loss: 0.1734 - val_consonant_output_loss: 0.1578
#  - root_recall: 0.8694 - vowel_recall: 0.9454 - consonant_recall: 0.9337 - final_score: 0.9044
# Epoch 4/20
# 176/176 [==============================] - 97s 553ms/step - loss: 0.2340 - root_output_loss: 0.1478 - vowel_output_loss: 0.0417 - consonant_output_loss: 0.0445 - val_loss: 0.8399 - val_root_output_loss: 0.4638 - val_vowel_output_loss: 0.2048 - val_consonant_output_loss: 0.2084
#  - root_recall: 0.8635 - vowel_recall: 0.9470 - consonant_recall: 0.9179 - final_score: 0.8980
# Epoch 5/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.2040 - root_output_loss: 0.1232 - vowel_output_loss: 0.0422 - consonant_output_loss: 0.0386 - val_loss: 0.5684 - val_root_output_loss: 0.5073 - val_vowel_output_loss: 0.1755 - val_consonant_output_loss: 0.2056
#  - root_recall: 0.8405 - vowel_recall: 0.9493 - consonant_recall: 0.9232 - final_score: 0.8884
# Epoch 6/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1702 - root_output_loss: 0.1033 - vowel_output_loss: 0.0328 - consonant_output_loss: 0.0341 - val_loss: 0.5890 - val_root_output_loss: 0.5938 - val_vowel_output_loss: 0.2422 - val_consonant_output_loss: 0.2205
#  - root_recall: 0.8550 - vowel_recall: 0.9235 - consonant_recall: 0.9281 - final_score: 0.8904
# Epoch 7/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1468 - root_output_loss: 0.0893 - vowel_output_loss: 0.0270 - consonant_output_loss: 0.0305 - val_loss: 0.8905 - val_root_output_loss: 0.5872 - val_vowel_output_loss: 0.1929 - val_consonant_output_loss: 0.1931
#  - root_recall: 0.8519 - vowel_recall: 0.9518 - consonant_recall: 0.9527 - final_score: 0.9021
# Epoch 8/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1385 - root_output_loss: 0.0867 - vowel_output_loss: 0.0280 - consonant_output_loss: 0.0237 - val_loss: 1.2068 - val_root_output_loss: 0.5589 - val_vowel_output_loss: 0.2867 - val_consonant_output_loss: 0.3451
#  - root_recall: 0.8441 - vowel_recall: 0.9198 - consonant_recall: 0.8558 - final_score: 0.8660
# Epoch 9/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1370 - root_output_loss: 0.0793 - vowel_output_loss: 0.0277 - consonant_output_loss: 0.0299 - val_loss: 0.8518 - val_root_output_loss: 0.5426 - val_vowel_output_loss: 0.2276 - val_consonant_output_loss: 0.1719
#  - root_recall: 0.8577 - vowel_recall: 0.9418 - consonant_recall: 0.9355 - final_score: 0.8981
# Epoch 10/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1226 - root_output_loss: 0.0779 - vowel_output_loss: 0.0223 - consonant_output_loss: 0.0225 - val_loss: 1.0150 - val_root_output_loss: 0.6233 - val_vowel_output_loss: 0.2566 - val_consonant_output_loss: 0.2214
#  - root_recall: 0.8563 - vowel_recall: 0.9444 - consonant_recall: 0.9489 - final_score: 0.9015
# Epoch 11/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1292 - root_output_loss: 0.0802 - vowel_output_loss: 0.0272 - consonant_output_loss: 0.0218 - val_loss: 1.3186 - val_root_output_loss: 0.6795 - val_vowel_output_loss: 0.2270 - val_consonant_output_loss: 0.2159
#  - root_recall: 0.8130 - vowel_recall: 0.9452 - consonant_recall: 0.9425 - final_score: 0.8784
# Epoch 12/20
# 176/176 [==============================] - 97s 553ms/step - loss: 0.1014 - root_output_loss: 0.0597 - vowel_output_loss: 0.0233 - consonant_output_loss: 0.0183 - val_loss: 1.0099 - val_root_output_loss: 0.5750 - val_vowel_output_loss: 0.2201 - val_consonant_output_loss: 0.2590
#  - root_recall: 0.8530 - vowel_recall: 0.9462 - consonant_recall: 0.9343 - final_score: 0.8966
# Epoch 13/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0864 - root_output_loss: 0.0572 - vowel_output_loss: 0.0139 - consonant_output_loss: 0.0153 - val_loss: 1.0697 - val_root_output_loss: 0.6072 - val_vowel_output_loss: 0.2593 - val_consonant_output_loss: 0.2811
#  - root_recall: 0.8561 - vowel_recall: 0.9484 - consonant_recall: 0.9371 - final_score: 0.8994
# Epoch 14/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0958 - root_output_loss: 0.0611 - vowel_output_loss: 0.0156 - consonant_output_loss: 0.0191 - val_loss: 1.2568 - val_root_output_loss: 0.6103 - val_vowel_output_loss: 0.2512 - val_consonant_output_loss: 0.3939
#  - root_recall: 0.8448 - vowel_recall: 0.9460 - consonant_recall: 0.8993 - final_score: 0.8837
# Epoch 15/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0993 - root_output_loss: 0.0585 - vowel_output_loss: 0.0225 - consonant_output_loss: 0.0183 - val_loss: 1.0657 - val_root_output_loss: 0.6203 - val_vowel_output_loss: 0.2139 - val_consonant_output_loss: 0.4005
#  - root_recall: 0.8455 - vowel_recall: 0.9596 - consonant_recall: 0.8039 - final_score: 0.8636
# Epoch 16/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0880 - root_output_loss: 0.0580 - vowel_output_loss: 0.0171 - consonant_output_loss: 0.0129 - val_loss: 1.4861 - val_root_output_loss: 0.7146 - val_vowel_output_loss: 0.2160 - val_consonant_output_loss: 0.2723
#  - root_recall: 0.8443 - vowel_recall: 0.9438 - consonant_recall: 0.9200 - final_score: 0.8881
# Epoch 17/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0920 - root_output_loss: 0.0596 - vowel_output_loss: 0.0205 - consonant_output_loss: 0.0120 - val_loss: 3.2558 - val_root_output_loss: 2.9155 - val_vowel_output_loss: 0.2466 - val_consonant_output_loss: 0.2645
#  - root_recall: 0.5791 - vowel_recall: 0.9529 - consonant_recall: 0.9256 - final_score: 0.7592
# Epoch 18/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0742 - root_output_loss: 0.0472 - vowel_output_loss: 0.0125 - consonant_output_loss: 0.0145 - val_loss: 1.2567 - val_root_output_loss: 0.6113 - val_vowel_output_loss: 0.2236 - val_consonant_output_loss: 0.3188
#  - root_recall: 0.8604 - vowel_recall: 0.9528 - consonant_recall: 0.8884 - final_score: 0.8905
# Epoch 19/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0814 - root_output_loss: 0.0515 - vowel_output_loss: 0.0158 - consonant_output_loss: 0.0141 - val_loss: 1.2466 - val_root_output_loss: 0.7108 - val_vowel_output_loss: 0.2294 - val_consonant_output_loss: 0.2739
#  - root_recall: 0.8671 - vowel_recall: 0.9465 - consonant_recall: 0.9342 - final_score: 0.9037
# Epoch 20/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0785 - root_output_loss: 0.0521 - vowel_output_loss: 0.0134 - consonant_output_loss: 0.0131 - val_loss: 1.2866 - val_root_output_loss: 0.7336 - val_vowel_output_loss: 0.2747 - val_consonant_output_loss: 0.2869
#  - root_recall: 0.8421 - vowel_recall: 0.9503 - consonant_recall: 0.9454 - final_score: 0.8950
# Epoch 1/20
# 176/176 [==============================] - 98s 557ms/step - loss: 0.8643 - root_output_loss: 0.5367 - vowel_output_loss: 0.1629 - consonant_output_loss: 0.1647 - val_loss: 0.6662 - val_root_output_loss: 0.3869 - val_vowel_output_loss: 0.1343 - val_consonant_output_loss: 0.1981
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#  - root_recall: 0.8657 - vowel_recall: 0.9499 - consonant_recall: 0.8703 - final_score: 0.8879
# Epoch 2/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.4061 - root_output_loss: 0.2615 - vowel_output_loss: 0.0705 - consonant_output_loss: 0.0742 - val_loss: 0.8420 - val_root_output_loss: 0.3597 - val_vowel_output_loss: 0.1100 - val_consonant_output_loss: 0.1499
#  - root_recall: 0.8797 - vowel_recall: 0.9640 - consonant_recall: 0.9153 - final_score: 0.9097
# Epoch 3/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.2335 - root_output_loss: 0.1548 - vowel_output_loss: 0.0380 - consonant_output_loss: 0.0408 - val_loss: 0.6981 - val_root_output_loss: 0.3654 - val_vowel_output_loss: 0.1424 - val_consonant_output_loss: 0.1987
#  - root_recall: 0.8832 - vowel_recall: 0.9582 - consonant_recall: 0.8867 - final_score: 0.9028
# Epoch 4/20
# 176/176 [==============================] - 97s 553ms/step - loss: 0.1640 - root_output_loss: 0.1056 - vowel_output_loss: 0.0276 - consonant_output_loss: 0.0309 - val_loss: 0.9824 - val_root_output_loss: 0.6487 - val_vowel_output_loss: 0.1603 - val_consonant_output_loss: 0.1975
#  - root_recall: 0.8355 - vowel_recall: 0.9460 - consonant_recall: 0.8981 - final_score: 0.8788
# Epoch 5/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1335 - root_output_loss: 0.0888 - vowel_output_loss: 0.0226 - consonant_output_loss: 0.0221 - val_loss: 1.0591 - val_root_output_loss: 0.3859 - val_vowel_output_loss: 0.1562 - val_consonant_output_loss: 0.1704
#  - root_recall: 0.8825 - vowel_recall: 0.9617 - consonant_recall: 0.9236 - final_score: 0.9126
# Epoch 6/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1197 - root_output_loss: 0.0778 - vowel_output_loss: 0.0234 - consonant_output_loss: 0.0185 - val_loss: 1.1288 - val_root_output_loss: 0.4303 - val_vowel_output_loss: 0.2389 - val_consonant_output_loss: 0.4500
#  - root_recall: 0.8843 - vowel_recall: 0.9355 - consonant_recall: 0.8414 - final_score: 0.8863
# Epoch 7/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1141 - root_output_loss: 0.0686 - vowel_output_loss: 0.0226 - consonant_output_loss: 0.0229 - val_loss: 0.7436 - val_root_output_loss: 0.3964 - val_vowel_output_loss: 0.2029 - val_consonant_output_loss: 0.2038
#  - root_recall: 0.8797 - vowel_recall: 0.9641 - consonant_recall: 0.8991 - final_score: 0.9056
# Epoch 8/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1110 - root_output_loss: 0.0697 - vowel_output_loss: 0.0214 - consonant_output_loss: 0.0200 - val_loss: 0.9468 - val_root_output_loss: 0.4751 - val_vowel_output_loss: 0.2050 - val_consonant_output_loss: 0.2924
#  - root_recall: 0.8850 - vowel_recall: 0.9555 - consonant_recall: 0.8446 - final_score: 0.8925
# Epoch 9/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0942 - root_output_loss: 0.0584 - vowel_output_loss: 0.0179 - consonant_output_loss: 0.0179 - val_loss: 1.3676 - val_root_output_loss: 0.6054 - val_vowel_output_loss: 0.2317 - val_consonant_output_loss: 0.2589
#  - root_recall: 0.8653 - vowel_recall: 0.9564 - consonant_recall: 0.9093 - final_score: 0.8991
# Epoch 10/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0960 - root_output_loss: 0.0628 - vowel_output_loss: 0.0148 - consonant_output_loss: 0.0184 - val_loss: 1.5858 - val_root_output_loss: 0.4743 - val_vowel_output_loss: 0.2476 - val_consonant_output_loss: 0.3236
#  - root_recall: 0.8836 - vowel_recall: 0.9498 - consonant_recall: 0.8631 - final_score: 0.8950
# Epoch 11/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0925 - root_output_loss: 0.0593 - vowel_output_loss: 0.0186 - consonant_output_loss: 0.0146 - val_loss: 0.9517 - val_root_output_loss: 0.4974 - val_vowel_output_loss: 0.2168 - val_consonant_output_loss: 0.2303
#  - root_recall: 0.8826 - vowel_recall: 0.9567 - consonant_recall: 0.9082 - final_score: 0.9075
# Epoch 12/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0897 - root_output_loss: 0.0573 - vowel_output_loss: 0.0201 - consonant_output_loss: 0.0123 - val_loss: 0.9961 - val_root_output_loss: 0.5428 - val_vowel_output_loss: 0.2561 - val_consonant_output_loss: 0.2892
#  - root_recall: 0.8754 - vowel_recall: 0.9368 - consonant_recall: 0.9064 - final_score: 0.8985
# Epoch 13/20
# 176/176 [==============================] - 97s 550ms/step - loss: 0.0774 - root_output_loss: 0.0482 - vowel_output_loss: 0.0156 - consonant_output_loss: 0.0135 - val_loss: 1.1262 - val_root_output_loss: 0.5551 - val_vowel_output_loss: 0.1767 - val_consonant_output_loss: 0.3883
#  - root_recall: 0.8736 - vowel_recall: 0.9594 - consonant_recall: 0.8256 - final_score: 0.8830
# Epoch 14/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0777 - root_output_loss: 0.0553 - vowel_output_loss: 0.0114 - consonant_output_loss: 0.0110 - val_loss: 2.5406 - val_root_output_loss: 2.2163 - val_vowel_output_loss: 0.2466 - val_consonant_output_loss: 0.2594
#  - root_recall: 0.6503 - vowel_recall: 0.9589 - consonant_recall: 0.8995 - final_score: 0.7898
# Epoch 15/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0673 - root_output_loss: 0.0475 - vowel_output_loss: 0.0109 - consonant_output_loss: 0.0089 - val_loss: 1.5775 - val_root_output_loss: 0.5692 - val_vowel_output_loss: 0.2480 - val_consonant_output_loss: 0.6206
#  - root_recall: 0.8806 - vowel_recall: 0.9526 - consonant_recall: 0.8206 - final_score: 0.8836
# Epoch 16/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0860 - root_output_loss: 0.0512 - vowel_output_loss: 0.0161 - consonant_output_loss: 0.0186 - val_loss: 1.0082 - val_root_output_loss: 0.6333 - val_vowel_output_loss: 0.2591 - val_consonant_output_loss: 0.2815
#  - root_recall: 0.8788 - vowel_recall: 0.9549 - consonant_recall: 0.8950 - final_score: 0.9019
# Epoch 17/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0696 - root_output_loss: 0.0468 - vowel_output_loss: 0.0091 - consonant_output_loss: 0.0137 - val_loss: 1.0722 - val_root_output_loss: 0.5933 - val_vowel_output_loss: 0.2685 - val_consonant_output_loss: 0.2151
#  - root_recall: 0.8796 - vowel_recall: 0.9566 - consonant_recall: 0.9257 - final_score: 0.9104
# Epoch 18/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0699 - root_output_loss: 0.0473 - vowel_output_loss: 0.0149 - consonant_output_loss: 0.0077 - val_loss: 1.1358 - val_root_output_loss: 0.6521 - val_vowel_output_loss: 0.2304 - val_consonant_output_loss: 0.2249
#  - root_recall: 0.8575 - vowel_recall: 0.9578 - consonant_recall: 0.9229 - final_score: 0.8989
# Epoch 19/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0698 - root_output_loss: 0.0482 - vowel_output_loss: 0.0147 - consonant_output_loss: 0.0068 - val_loss: 0.9263 - val_root_output_loss: 0.6397 - val_vowel_output_loss: 0.3051 - val_consonant_output_loss: 0.2602
#  - root_recall: 0.8746 - vowel_recall: 0.9434 - consonant_recall: 0.9170 - final_score: 0.9024
# Epoch 20/20
# 176/176 [==============================] - 97s 553ms/step - loss: 0.0660 - root_output_loss: 0.0408 - vowel_output_loss: 0.0130 - consonant_output_loss: 0.0122 - val_loss: 1.6466 - val_root_output_loss: 0.6695 - val_vowel_output_loss: 0.2156 - val_consonant_output_loss: 0.2914
#  - root_recall: 0.8509 - vowel_recall: 0.9542 - consonant_recall: 0.9290 - final_score: 0.8962
# Epoch 1/20
# 176/176 [==============================] - 98s 558ms/step - loss: 0.8233 - root_output_loss: 0.5149 - vowel_output_loss: 0.1543 - consonant_output_loss: 0.1541 - val_loss: 1.2398 - val_root_output_loss: 0.4933 - val_vowel_output_loss: 0.1439 - val_consonant_output_loss: 0.4680
#  - root_recall: 0.8606 - vowel_recall: 0.9361 - consonant_recall: 0.8130 - final_score: 0.8676
# Epoch 2/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.3736 - root_output_loss: 0.2368 - vowel_output_loss: 0.0644 - consonant_output_loss: 0.0723 - val_loss: 0.6874 - val_root_output_loss: 0.3639 - val_vowel_output_loss: 0.1277 - val_consonant_output_loss: 0.1299
#  - root_recall: 0.9009 - vowel_recall: 0.9555 - consonant_recall: 0.9366 - final_score: 0.9235
# Epoch 3/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.2050 - root_output_loss: 0.1386 - vowel_output_loss: 0.0303 - consonant_output_loss: 0.0362 - val_loss: 0.8239 - val_root_output_loss: 0.3592 - val_vowel_output_loss: 0.1346 - val_consonant_output_loss: 0.1312
#  - root_recall: 0.9121 - vowel_recall: 0.9596 - consonant_recall: 0.9543 - final_score: 0.9345
# Epoch 4/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1409 - root_output_loss: 0.0962 - vowel_output_loss: 0.0240 - consonant_output_loss: 0.0207 - val_loss: 0.5054 - val_root_output_loss: 0.3692 - val_vowel_output_loss: 0.1410 - val_consonant_output_loss: 0.1517
#  - root_recall: 0.9039 - vowel_recall: 0.9589 - consonant_recall: 0.9463 - final_score: 0.9282
# Epoch 5/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.1101 - root_output_loss: 0.0678 - vowel_output_loss: 0.0223 - consonant_output_loss: 0.0200 - val_loss: 0.7922 - val_root_output_loss: 0.5083 - val_vowel_output_loss: 0.1843 - val_consonant_output_loss: 0.1817
#  - root_recall: 0.8950 - vowel_recall: 0.9525 - consonant_recall: 0.9372 - final_score: 0.9199
# Epoch 6/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.1072 - root_output_loss: 0.0650 - vowel_output_loss: 0.0220 - consonant_output_loss: 0.0202 - val_loss: 0.5301 - val_root_output_loss: 0.4490 - val_vowel_output_loss: 0.1406 - val_consonant_output_loss: 0.1968
#  - root_recall: 0.8958 - vowel_recall: 0.9593 - consonant_recall: 0.9489 - final_score: 0.9250
# Epoch 7/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0956 - root_output_loss: 0.0614 - vowel_output_loss: 0.0147 - consonant_output_loss: 0.0194 - val_loss: 0.6892 - val_root_output_loss: 0.4714 - val_vowel_output_loss: 0.1876 - val_consonant_output_loss: 0.1835
#  - root_recall: 0.8934 - vowel_recall: 0.9682 - consonant_recall: 0.9308 - final_score: 0.9214
# Epoch 8/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0865 - root_output_loss: 0.0576 - vowel_output_loss: 0.0135 - consonant_output_loss: 0.0154 - val_loss: 0.8148 - val_root_output_loss: 0.4802 - val_vowel_output_loss: 0.1848 - val_consonant_output_loss: 0.1953
#  - root_recall: 0.9014 - vowel_recall: 0.9611 - consonant_recall: 0.9394 - final_score: 0.9258
# Epoch 9/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0845 - root_output_loss: 0.0498 - vowel_output_loss: 0.0218 - consonant_output_loss: 0.0130 - val_loss: 1.0169 - val_root_output_loss: 0.5396 - val_vowel_output_loss: 0.1749 - val_consonant_output_loss: 0.2092
#  - root_recall: 0.8919 - vowel_recall: 0.9596 - consonant_recall: 0.9487 - final_score: 0.9230
# Epoch 10/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0717 - root_output_loss: 0.0469 - vowel_output_loss: 0.0141 - consonant_output_loss: 0.0107 - val_loss: 1.2868 - val_root_output_loss: 0.5370 - val_vowel_output_loss: 0.1575 - val_consonant_output_loss: 0.1606
#  - root_recall: 0.8918 - vowel_recall: 0.9571 - consonant_recall: 0.9514 - final_score: 0.9230
# Epoch 11/20
# 176/176 [==============================] - 97s 551ms/step - loss: 0.0738 - root_output_loss: 0.0511 - vowel_output_loss: 0.0112 - consonant_output_loss: 0.0115 - val_loss: 0.7650 - val_root_output_loss: 0.4944 - val_vowel_output_loss: 0.2012 - val_consonant_output_loss: 0.1978
#  - root_recall: 0.9004 - vowel_recall: 0.9505 - consonant_recall: 0.9461 - final_score: 0.9243
# Epoch 12/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0765 - root_output_loss: 0.0495 - vowel_output_loss: 0.0156 - consonant_output_loss: 0.0114 - val_loss: 1.0253 - val_root_output_loss: 0.5754 - val_vowel_output_loss: 0.2307 - val_consonant_output_loss: 0.2476
#  - root_recall: 0.8980 - vowel_recall: 0.9470 - consonant_recall: 0.9353 - final_score: 0.9196
# Epoch 13/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0724 - root_output_loss: 0.0460 - vowel_output_loss: 0.0147 - consonant_output_loss: 0.0117 - val_loss: 1.0079 - val_root_output_loss: 0.5157 - val_vowel_output_loss: 0.1623 - val_consonant_output_loss: 0.2110
#  - root_recall: 0.9018 - vowel_recall: 0.9536 - consonant_recall: 0.9447 - final_score: 0.9255
# Epoch 14/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0688 - root_output_loss: 0.0431 - vowel_output_loss: 0.0132 - consonant_output_loss: 0.0125 - val_loss: 1.0517 - val_root_output_loss: 0.5511 - val_vowel_output_loss: 0.1910 - val_consonant_output_loss: 0.4395
#  - root_recall: 0.9052 - vowel_recall: 0.9593 - consonant_recall: 0.8917 - final_score: 0.9154
# Epoch 15/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0672 - root_output_loss: 0.0473 - vowel_output_loss: 0.0100 - consonant_output_loss: 0.0099 - val_loss: 0.5160 - val_root_output_loss: 0.5689 - val_vowel_output_loss: 0.2204 - val_consonant_output_loss: 0.2248
#  - root_recall: 0.8850 - vowel_recall: 0.9595 - consonant_recall: 0.9508 - final_score: 0.9201
# Epoch 16/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0745 - root_output_loss: 0.0461 - vowel_output_loss: 0.0167 - consonant_output_loss: 0.0117 - val_loss: 1.0947 - val_root_output_loss: 0.6082 - val_vowel_output_loss: 0.3971 - val_consonant_output_loss: 0.2504
#  - root_recall: 0.8916 - vowel_recall: 0.9216 - consonant_recall: 0.9211 - final_score: 0.9065
# Epoch 17/20
# 176/176 [==============================] - 97s 553ms/step - loss: 0.0622 - root_output_loss: 0.0447 - vowel_output_loss: 0.0089 - consonant_output_loss: 0.0086 - val_loss: 1.3103 - val_root_output_loss: 0.7003 - val_vowel_output_loss: 0.2165 - val_consonant_output_loss: 0.4045
#  - root_recall: 0.8862 - vowel_recall: 0.9534 - consonant_recall: 0.8801 - final_score: 0.9015
# Epoch 18/20
# 176/176 [==============================] - 97s 553ms/step - loss: 0.0586 - root_output_loss: 0.0396 - vowel_output_loss: 0.0096 - consonant_output_loss: 0.0094 - val_loss: 0.9775 - val_root_output_loss: 0.5600 - val_vowel_output_loss: 0.2324 - val_consonant_output_loss: 0.2534
#  - root_recall: 0.8916 - vowel_recall: 0.9595 - consonant_recall: 0.9333 - final_score: 0.9190
# Epoch 19/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0610 - root_output_loss: 0.0368 - vowel_output_loss: 0.0121 - consonant_output_loss: 0.0121 - val_loss: 0.8183 - val_root_output_loss: 0.5949 - val_vowel_output_loss: 0.2672 - val_consonant_output_loss: 0.2522
#  - root_recall: 0.9002 - vowel_recall: 0.9591 - consonant_recall: 0.9420 - final_score: 0.9254
# Epoch 20/20
# 176/176 [==============================] - 97s 552ms/step - loss: 0.0688 - root_output_loss: 0.0431 - vowel_output_loss: 0.0099 - consonant_output_loss: 0.0157 - val_loss: 1.3921 - val_root_output_loss: 0.7107 - val_vowel_output_loss: 0.2271 - val_consonant_output_loss: 0.6914
#  - root_recall: 0.8853 - vowel_recall: 0.9580 - consonant_recall: 0.7934 - final_score: 0.8805

# %%
model.save('multi_branch_CNN.h5')

# %% [markdown]
# # Results

# %%
results = {key: value + history[1][key] + history[2][key] +\
           history[3][key] for key, value in history[0].items()}
results_df = pd.DataFrame(results, columns=results.keys())

# %%
display(results_df)
# Out:
#      val_loss  val_root_output_loss  val_vowel_output_loss  \
# 0   12.451693              7.982618               2.334415
# 1    7.871705              5.894032               1.035788
# 2    3.316375              2.492519               0.352974
# 3    1.555556              0.912747               0.224367
# 4    0.960899              0.547215               0.190714
# ..        ...                   ...                    ...
# 75   1.094653              0.608210               0.397090
# 76   1.310273              0.700324               0.216524
# 77   0.977466              0.559997               0.232408
# 78   0.818299              0.594869               0.267186
# 79   1.392075              0.710661               0.227091
#
#     val_consonant_output_loss      loss  root_output_loss  vowel_output_loss  \
# 0                    2.274352  5.078113          3.778103           0.662138
# 1                    1.191072  2.290206          1.684508           0.301962
# 2                    0.507292  1.332630          0.892407           0.217979
# 3                    0.230783  0.944606          0.593785           0.170350
# 4                    0.207285  0.718677          0.433137           0.141449
# ..                        ...       ...               ...                ...
# 75                   0.250353  0.074049          0.046058           0.016705
# 76                   0.404538  0.062287          0.044703           0.008899
# 77                   0.253424  0.058519          0.039618           0.009590
# 78                   0.252158  0.060961          0.036799           0.012141
# 79                   0.691415  0.068634          0.043149           0.009862
#
#     consonant_output_loss  root_recall  vowel_recall  consonant_recall  \
# 0                0.637872     0.007293      0.119200          0.184167
# 1                0.305839     0.041952      0.435680          0.456382
# 2                0.222806     0.406277      0.806598          0.554787
# 3                0.181256     0.727692      0.904176          0.832832
# 4                0.145174     0.809703      0.927089          0.853829
# ..                    ...          ...           ...               ...
# 75               0.011729     0.891645      0.921557          0.921096
# 76               0.008608     0.886228      0.953392          0.880103
# 77               0.009376     0.891624      0.959547          0.933308
# 78               0.012089     0.900227      0.959128          0.942011
# 79               0.015745     0.885336      0.958009          0.793402
#
#     final_score
# 0      0.079488
# 1      0.243992
# 2      0.543485
# 3      0.798098
# 4      0.850081
# ..          ...
# 75     0.906486
# 76     0.901488
# 77     0.919026
# 78     0.925399
# 79     0.880521
#
# [80 rows x 12 columns]

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax = sns.lineplot(data=results_df.loc[:,['root_recall', 'vowel_recall', 
                                         'consonant_recall', 'final_score']], linestyle=None)
ax.set_xlabel('epochs', labelpad=15, fontsize=15)
ax.set_ylabel('score', labelpad=15, fontsize=15)
ax.set_title('Validation scores', pad=15, fontsize=20)
plt.yticks(np.arange(0, 1.1, step=0.1))
ax.grid(axis='both', linestyle=':', linewidth=1)

# %%
fig, ax1 = plt.subplots(figsize=(10,8))
ax1 = sns.lineplot(data=results_df.loc[:,['val_loss', 'val_root_output_loss', 'val_vowel_output_loss',
                                          'val_consonant_output_loss']], linestyle=None)
ax1.set_xlabel('epochs', labelpad=15, fontsize=15)
ax1.set_ylabel('loss', labelpad=15, fontsize=15)
ax1.set_title('Validation losses', pad=15, fontsize=20)
ax1.grid(axis='both', linestyle=':', linewidth=1)

# %%
fig, ax2 = plt.subplots(figsize=(10,8))
ax2 = sns.lineplot(data=results_df.loc[:,['loss', 'root_output_loss','vowel_output_loss', 
                                          'consonant_output_loss']], linestyle=None)
ax2.set_xlabel('epochs', labelpad=15, fontsize=15)
ax2.set_ylabel('loss', labelpad=15, fontsize=15)
ax2.set_title('Training losses', pad=15, fontsize=20)
ax2.grid(axis='both', linestyle=':', linewidth=1)
